# %%
## consume to mongodb
from kafka import KafkaConsumer
import sys, json, pymongo
# from elasticsearch import Elasticsearch
# import time, datetime


if __name__ == "__main__":

    # 與 MongoDB連線
    client = pymongo.MongoClient(host="mongodb", port=27017)
    # 指定為 test 資料庫
    db = client.test
    # 指定 temp_humidity 集合, MongoDB的每個資料庫又包含許多集合(collection), 類似於關聯性資料庫中的表
    collection = db.bpm

    # 設定要連線到Kafka集群的相關設定, 產生一個Kafka的Consumer的實例
    consumer = KafkaConsumer(
        # 指定Kafka集群伺服器
        bootstrap_servers=["kafka:9092"],
        # ConsumerGroup的名稱, 可以不指定
        #group_id="cg_001",
        # 指定msgKey的反序列化器, 若Key為None, 無法反序列化
        # key_deserializer=bytes.decode,
        # 指定msgValue的反序列化器
        #value_deserializer=bytes.decode,
        value_deserializer=lambda m: json.loads(m.decode('ascii')),
        # 是否從這個ConsumerGroup尚未讀取的partition / offset開始讀
        auto_offset_reset="earliest",
    )
   
    # 讓Consumer向Kafka集群訂閱指定的topic
    consumer.subscribe(topics="bpm")
    
    #es = Elasticsearch('http://elasticsearch:9200')
    
    
    # 持續的拉取Kafka有進來的訊息
    try:
        print("Now listening for incoming messages ...")
        # 持續監控是否有新的record進來
        for record in consumer:
            topic = record.topic
            partition = record.partition
            offset = record.offset
            timestamp = record.timestamp
            # 取出msgKey與msgValue
            msgKey = record.key
            msgValue = record.value
            # 秀出metadata與msgKey & msgValue訊息
            print("topic=%s, partition=%s, offset=%s : (key=%s, value=%s)" % (record.topic, record.partition, 
                                                                              record.offset, record.key, record.value))
            j = {"device_id": msgValue["device_id"], "timestamp": msgValue["timestamp"], "bpm": msgValue["bpm"]}
            print("json=",  j)
            
            # 將資料存入 mongodb
            # 存入單筆
            result = collection.insert_one(j)
            # 存入多筆
            #result = collection.insert_many()
            print(result)
            #res = es.index(index="temp_humidity1", doc_type='tweet', id=datetime.now(), body=j)
            #print(res['result'])

    except:
        # 錯誤處理
        e_type, e_value, e_traceback = sys.exc_info()
        print("type ==> %s" % (e_type))
        print("value ==> %s" % (e_value))
        print("traceback ==> file name: %s" % (e_traceback.tb_frame.f_code.co_filename))
        print("traceback ==> line no: %s" % (e_traceback.tb_lineno))
        print("traceback ==> function name: %s" % (e_traceback.tb_frame.f_code.co_name))
    finally:
        consumer.close()
# Out:
# Now listening for incoming messages ...
# topic=bpm, partition=0, offset=0 : (key=None, value={'timestamp': '2019-09-21 16:06:18', 'bpm': '43', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:18', 'bpm': '43'}
# <pymongo.results.InsertOneResult object at 0x7fa5a44bdf88>
# topic=bpm, partition=0, offset=1 : (key=None, value={'timestamp': '2019-09-21 16:06:19', 'bpm': '44', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:19', 'bpm': '44'}
# <pymongo.results.InsertOneResult object at 0x7fa5a44bdfc8>
# topic=bpm, partition=0, offset=2 : (key=None, value={'timestamp': '2019-09-21 16:06:21', 'bpm': '42', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:21', 'bpm': '42'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4458ac8>
# topic=bpm, partition=0, offset=3 : (key=None, value={'timestamp': '2019-09-21 16:06:22', 'bpm': '43', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:22', 'bpm': '43'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4458d48>
# topic=bpm, partition=0, offset=4 : (key=None, value={'timestamp': '2019-09-21 16:06:24', 'bpm': '42', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:24', 'bpm': '42'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4458d88>
# topic=bpm, partition=0, offset=5 : (key=None, value={'timestamp': '2019-09-21 16:06:25', 'bpm': '42', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:25', 'bpm': '42'}
# <pymongo.results.InsertOneResult object at 0x7fa5a44694c8>
# topic=bpm, partition=0, offset=6 : (key=None, value={'timestamp': '2019-09-21 16:06:27', 'bpm': '42', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:27', 'bpm': '42'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4469848>
# topic=bpm, partition=0, offset=7 : (key=None, value={'timestamp': '2019-09-21 16:06:27', 'bpm': '44', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:27', 'bpm': '44'}
# <pymongo.results.InsertOneResult object at 0x7fa5a5919c88>
# topic=bpm, partition=0, offset=8 : (key=None, value={'timestamp': '2019-09-21 16:06:28', 'bpm': '46', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:28', 'bpm': '46'}
# <pymongo.results.InsertOneResult object at 0x7fa5a44699c8>
# topic=bpm, partition=0, offset=9 : (key=None, value={'timestamp': '2019-09-21 16:06:29', 'bpm': '48', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:29', 'bpm': '48'}
# <pymongo.results.InsertOneResult object at 0x7fa5a5919c88>
# topic=bpm, partition=0, offset=10 : (key=None, value={'timestamp': '2019-09-21 16:06:31', 'bpm': '47', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:31', 'bpm': '47'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4469848>
# topic=bpm, partition=0, offset=11 : (key=None, value={'timestamp': '2019-09-21 16:06:32', 'bpm': '46', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:32', 'bpm': '46'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4469748>
# topic=bpm, partition=0, offset=12 : (key=None, value={'timestamp': '2019-09-21 16:06:33', 'bpm': '50', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:33', 'bpm': '50'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4469948>
# topic=bpm, partition=0, offset=13 : (key=None, value={'timestamp': '2019-09-21 16:06:33', 'bpm': '54', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:33', 'bpm': '54'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4469148>
# topic=bpm, partition=0, offset=14 : (key=None, value={'timestamp': '2019-09-21 16:06:34', 'bpm': '57', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:34', 'bpm': '57'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4469848>
# topic=bpm, partition=0, offset=15 : (key=None, value={'timestamp': '2019-09-21 16:06:35', 'bpm': '61', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:35', 'bpm': '61'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4469748>
# topic=bpm, partition=0, offset=16 : (key=None, value={'timestamp': '2019-09-21 16:06:36', 'bpm': '63', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:36', 'bpm': '63'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4469948>
# topic=bpm, partition=0, offset=17 : (key=None, value={'timestamp': '2019-09-21 16:06:37', 'bpm': '63', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:37', 'bpm': '63'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4458a88>
# topic=bpm, partition=0, offset=18 : (key=None, value={'timestamp': '2019-09-21 16:06:38', 'bpm': '63', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:38', 'bpm': '63'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4469848>
# topic=bpm, partition=0, offset=19 : (key=None, value={'timestamp': '2019-09-21 16:06:39', 'bpm': '63', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:39', 'bpm': '63'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4458a88>
# topic=bpm, partition=0, offset=20 : (key=None, value={'timestamp': '2019-09-21 16:06:39', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:39', 'bpm': '70'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4469488>
# topic=bpm, partition=0, offset=21 : (key=None, value={'timestamp': '2019-09-21 16:06:40', 'bpm': '73', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:40', 'bpm': '73'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4458a88>
# topic=bpm, partition=0, offset=22 : (key=None, value={'timestamp': '2019-09-21 16:06:41', 'bpm': '73', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:41', 'bpm': '73'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4469a48>
# topic=bpm, partition=0, offset=23 : (key=None, value={'timestamp': '2019-09-21 16:06:42', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:42', 'bpm': '70'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4458a88>
# topic=bpm, partition=0, offset=24 : (key=None, value={'timestamp': '2019-09-21 16:06:43', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:43', 'bpm': '70'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4469488>
# topic=bpm, partition=0, offset=25 : (key=None, value={'timestamp': '2019-09-21 16:06:44', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:44', 'bpm': '70'}
# <pymongo.results.InsertOneResult object at 0x7fa5a5919c88>
# topic=bpm, partition=0, offset=26 : (key=None, value={'timestamp': '2019-09-21 16:06:44', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:44', 'bpm': '70'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4469a48>
# topic=bpm, partition=0, offset=27 : (key=None, value={'timestamp': '2019-09-21 16:06:45', 'bpm': '71', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:45', 'bpm': '71'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4458a88>
# topic=bpm, partition=0, offset=28 : (key=None, value={'timestamp': '2019-09-21 16:06:46', 'bpm': '74', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:46', 'bpm': '74'}
# <pymongo.results.InsertOneResult object at 0x7fa5a5919c88>
# topic=bpm, partition=0, offset=29 : (key=None, value={'timestamp': '2019-09-21 16:06:46', 'bpm': '78', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:46', 'bpm': '78'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4458a88>
# topic=bpm, partition=0, offset=30 : (key=None, value={'timestamp': '2019-09-21 16:06:47', 'bpm': '84', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:47', 'bpm': '84'}
# <pymongo.results.InsertOneResult object at 0x7fa5a5919c88>
# topic=bpm, partition=0, offset=31 : (key=None, value={'timestamp': '2019-09-21 16:06:47', 'bpm': '90', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:47', 'bpm': '90'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4458a88>
# topic=bpm, partition=0, offset=32 : (key=None, value={'timestamp': '2019-09-21 16:06:47', 'bpm': '95', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:47', 'bpm': '95'}
# <pymongo.results.InsertOneResult object at 0x7fa5a5919c88>
# topic=bpm, partition=0, offset=33 : (key=None, value={'timestamp': '2019-09-21 16:06:49', 'bpm': '89', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:49', 'bpm': '89'}
# <pymongo.results.InsertOneResult object at 0x7fa5a44696c8>
# topic=bpm, partition=0, offset=34 : (key=None, value={'timestamp': '2019-09-21 16:06:49', 'bpm': '90', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:06:49', 'bpm': '90'}
# <pymongo.results.InsertOneResult object at 0x7fa5a5919c88>
# topic=bpm, partition=0, offset=35 : (key=None, value={'timestamp': '2019-09-21 16:07:01', 'bpm': '57', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:07:01', 'bpm': '57'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4469808>
# topic=bpm, partition=0, offset=36 : (key=None, value={'timestamp': '2019-09-21 16:07:02', 'bpm': '59', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:07:02', 'bpm': '59'}
# <pymongo.results.InsertOneResult object at 0x7fa5a5919c88>
# topic=bpm, partition=0, offset=37 : (key=None, value={'timestamp': '2019-09-21 16:07:02', 'bpm': '62', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:07:02', 'bpm': '62'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4469a08>
# topic=bpm, partition=0, offset=38 : (key=None, value={'timestamp': '2019-09-21 16:07:03', 'bpm': '67', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:07:03', 'bpm': '67'}
# <pymongo.results.InsertOneResult object at 0x7fa5a5919c88>
# topic=bpm, partition=0, offset=39 : (key=None, value={'timestamp': '2019-09-21 16:07:03', 'bpm': '73', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:07:03', 'bpm': '73'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4458a88>
# topic=bpm, partition=0, offset=40 : (key=None, value={'timestamp': '2019-09-21 16:07:03', 'bpm': '80', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:07:03', 'bpm': '80'}
# <pymongo.results.InsertOneResult object at 0x7fa5a5919c88>
# topic=bpm, partition=0, offset=41 : (key=None, value={'timestamp': '2019-09-21 16:07:04', 'bpm': '88', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:07:04', 'bpm': '88'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4458a88>
# topic=bpm, partition=0, offset=42 : (key=None, value={'timestamp': '2019-09-21 16:07:04', 'bpm': '98', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:07:04', 'bpm': '98'}
# <pymongo.results.InsertOneResult object at 0x7fa5a5919c88>
# topic=bpm, partition=0, offset=43 : (key=None, value={'timestamp': '2019-09-21 16:07:04', 'bpm': '112', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:07:04', 'bpm': '112'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4458a88>
# topic=bpm, partition=0, offset=44 : (key=None, value={'timestamp': '2019-09-21 16:07:05', 'bpm': '128', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:07:05', 'bpm': '128'}
# <pymongo.results.InsertOneResult object at 0x7fa5a5919c88>
# topic=bpm, partition=0, offset=45 : (key=None, value={'timestamp': '2019-09-21 16:07:05', 'bpm': '143', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:07:05', 'bpm': '143'}
# <pymongo.results.InsertOneResult object at 0x7fa5a58fb648>
# topic=bpm, partition=0, offset=46 : (key=None, value={'timestamp': '2019-09-21 16:07:06', 'bpm': '159', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': '2019-09-21 16:07:06', 'bpm': '159'}
# <pymongo.results.InsertOneResult object at 0x7fa5a4458d88>
# type ==> <class 'KeyboardInterrupt'>
# value ==>
# traceback ==> file name: <ipython-input-2-25a54f03b03b>
# traceback ==> line no: 42
# traceback ==> function name: <module>

# %%
## consume to Elasticsearch
from kafka import KafkaConsumer
import sys, json
# import pymongo
from elasticsearch import Elasticsearch
import time, datetime


if __name__ == "__main__":

    # 與 MongoDB連線
#     client = pymongo.MongoClient(host="mongodb", port=27017)
#     # 指定為 test 資料庫
#     db = client.test
#     # 指定 temp_humidity 集合, MongoDB的每個資料庫又包含許多集合(collection), 類似於關聯性資料庫中的表
#     collection = db.bpm

    # 設定要連線到Kafka集群的相關設定, 產生一個Kafka的Consumer的實例
    consumer = KafkaConsumer(
        # 指定Kafka集群伺服器
        bootstrap_servers=["kafka:9092"],
        # ConsumerGroup的名稱, 可以不指定
        #group_id="cg_001",
        # 指定msgKey的反序列化器, 若Key為None, 無法反序列化
        # key_deserializer=bytes.decode,
        # 指定msgValue的反序列化器
        #value_deserializer=bytes.decode,
        value_deserializer=lambda m: json.loads(m.decode('ascii')),
        # 是否從這個ConsumerGroup尚未讀取的partition / offset開始讀
        auto_offset_reset="earliest",
    )
   
    # 讓Consumer向Kafka集群訂閱指定的topic
    consumer.subscribe(topics="bpm")
    
    es = Elasticsearch('http://elasticsearch:9200')
    
    
    # 持續的拉取Kafka有進來的訊息
    try:
        print("Now listening for incoming messages ...")
        # 持續監控是否有新的record進來
        for record in consumer:
            topic = record.topic
            partition = record.partition
            offset = record.offset
            timestamp = record.timestamp
            # 取出msgKey與msgValue
            msgKey = record.key
            msgValue = record.value
            # 秀出metadata與msgKey & msgValue訊息
            time = datetime.datetime.now()
            print("topic=%s, partition=%s, offset=%s : (key=%s, value=%s)" % (record.topic, record.partition, 
                                                                              record.offset, record.key, record.value))
            j = {"device_id": msgValue["device_id"], "timestamp": time, "bpm": int(msgValue["bpm"])}
            print("json=",  j)
            
#             # 將資料存入 mongodb
#             # 存入單筆
#             result = collection.insert_one(j)
#             # 存入多筆
#             # result = collection.insert_many()
#             print(result)


            res = es.index(index="bpm", doc_type='tweet', id=time, body=j)
            print(res['result'])

    except:
        # 錯誤處理
        e_type, e_value, e_traceback = sys.exc_info()
        print("type ==> %s" % (e_type))
        print("value ==> %s" % (e_value))
        print("traceback ==> file name: %s" % (e_traceback.tb_frame.f_code.co_filename))
        print("traceback ==> line no: %s" % (e_traceback.tb_lineno))
        print("traceback ==> function name: %s" % (e_traceback.tb_frame.f_code.co_name))
    finally:
        consumer.close()
# Out:
# Now listening for incoming messages ...
# topic=bpm, partition=0, offset=0 : (key=None, value={'timestamp': '2019-09-21 16:28:39', 'bpm': '65', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 158675), 'bpm': 65}
# created
# topic=bpm, partition=0, offset=1 : (key=None, value={'timestamp': '2019-09-21 16:28:41', 'bpm': '60', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 228428), 'bpm': 60}
# created
# topic=bpm, partition=0, offset=2 : (key=None, value={'timestamp': '2019-09-21 16:28:42', 'bpm': '59', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 234481), 'bpm': 59}
# created
# topic=bpm, partition=0, offset=3 : (key=None, value={'timestamp': '2019-09-21 16:28:42', 'bpm': '61', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 241677), 'bpm': 61}
# created
# topic=bpm, partition=0, offset=4 : (key=None, value={'timestamp': '2019-09-21 16:28:43', 'bpm': '62', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 246410), 'bpm': 62}
# created
# topic=bpm, partition=0, offset=5 : (key=None, value={'timestamp': '2019-09-21 16:29:49', 'bpm': '44', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 251531), 'bpm': 44}
# created
# topic=bpm, partition=0, offset=6 : (key=None, value={'timestamp': '2019-09-21 16:29:56', 'bpm': '43', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 257900), 'bpm': 43}
# created
# topic=bpm, partition=0, offset=7 : (key=None, value={'timestamp': '2019-09-21 16:29:58', 'bpm': '42', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 262526), 'bpm': 42}
# created
# topic=bpm, partition=0, offset=8 : (key=None, value={'timestamp': '2019-09-21 16:29:59', 'bpm': '42', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 266998), 'bpm': 42}
# created
# topic=bpm, partition=0, offset=9 : (key=None, value={'timestamp': '2019-09-21 16:30:00', 'bpm': '42', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 272769), 'bpm': 42}
# created
# topic=bpm, partition=0, offset=10 : (key=None, value={'timestamp': '2019-09-21 16:30:01', 'bpm': '44', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 277652), 'bpm': 44}
# created
# topic=bpm, partition=0, offset=11 : (key=None, value={'timestamp': '2019-09-21 16:30:02', 'bpm': '46', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 282970), 'bpm': 46}
# created
# topic=bpm, partition=0, offset=12 : (key=None, value={'timestamp': '2019-09-21 16:30:03', 'bpm': '48', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 287334), 'bpm': 48}
# created
# topic=bpm, partition=0, offset=13 : (key=None, value={'timestamp': '2019-09-21 16:30:04', 'bpm': '50', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 292118), 'bpm': 50}
# created
# topic=bpm, partition=0, offset=14 : (key=None, value={'timestamp': '2019-09-21 16:30:05', 'bpm': '52', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 296888), 'bpm': 52}
# created
# topic=bpm, partition=0, offset=15 : (key=None, value={'timestamp': '2019-09-21 16:30:05', 'bpm': '55', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 300879), 'bpm': 55}
# created
# topic=bpm, partition=0, offset=16 : (key=None, value={'timestamp': '2019-09-21 16:30:06', 'bpm': '57', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 305751), 'bpm': 57}
# created
# topic=bpm, partition=0, offset=17 : (key=None, value={'timestamp': '2019-09-21 16:30:07', 'bpm': '66', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 309989), 'bpm': 66}
# created
# topic=bpm, partition=0, offset=18 : (key=None, value={'timestamp': '2019-09-21 16:30:35', 'bpm': '66', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 313956), 'bpm': 66}
# created
# topic=bpm, partition=0, offset=19 : (key=None, value={'timestamp': '2019-09-21 16:31:00', 'bpm': '46', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 328902), 'bpm': 46}
# created
# topic=bpm, partition=0, offset=20 : (key=None, value={'timestamp': '2019-09-21 16:31:01', 'bpm': '48', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 333442), 'bpm': 48}
# created
# topic=bpm, partition=0, offset=21 : (key=None, value={'timestamp': '2019-09-21 16:31:09', 'bpm': '133', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 338463), 'bpm': 133}
# created
# topic=bpm, partition=0, offset=22 : (key=None, value={'timestamp': '2019-09-21 16:31:10', 'bpm': '138', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 342747), 'bpm': 138}
# created
# topic=bpm, partition=0, offset=23 : (key=None, value={'timestamp': '2019-09-21 16:31:14', 'bpm': '49', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 347459), 'bpm': 49}
# created
# topic=bpm, partition=0, offset=24 : (key=None, value={'timestamp': '2019-09-21 16:31:14', 'bpm': '51', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 352062), 'bpm': 51}
# created
# topic=bpm, partition=0, offset=25 : (key=None, value={'timestamp': '2019-09-21 16:31:15', 'bpm': '53', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 356114), 'bpm': 53}
# created
# topic=bpm, partition=0, offset=26 : (key=None, value={'timestamp': '2019-09-21 16:31:16', 'bpm': '56', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 360682), 'bpm': 56}
# created
# topic=bpm, partition=0, offset=27 : (key=None, value={'timestamp': '2019-09-21 16:31:27', 'bpm': '53', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 366441), 'bpm': 53}
# created
# topic=bpm, partition=0, offset=28 : (key=None, value={'timestamp': '2019-09-21 16:32:19', 'bpm': '137', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 371569), 'bpm': 137}
# created
# topic=bpm, partition=0, offset=29 : (key=None, value={'timestamp': '2019-09-21 16:32:30', 'bpm': '43', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 376485), 'bpm': 43}
# created
# topic=bpm, partition=0, offset=30 : (key=None, value={'timestamp': '2019-09-21 16:32:32', 'bpm': '41', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 380580), 'bpm': 41}
# created
# topic=bpm, partition=0, offset=31 : (key=None, value={'timestamp': '2019-09-21 16:32:34', 'bpm': '41', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 384786), 'bpm': 41}
# created
# topic=bpm, partition=0, offset=32 : (key=None, value={'timestamp': '2019-09-21 16:32:35', 'bpm': '42', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 389156), 'bpm': 42}
# created
# topic=bpm, partition=0, offset=33 : (key=None, value={'timestamp': '2019-09-21 16:32:35', 'bpm': '45', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 393317), 'bpm': 45}
# created
# topic=bpm, partition=0, offset=34 : (key=None, value={'timestamp': '2019-09-21 16:32:36', 'bpm': '48', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 397088), 'bpm': 48}
# created
# topic=bpm, partition=0, offset=35 : (key=None, value={'timestamp': '2019-09-21 16:32:36', 'bpm': '52', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 400571), 'bpm': 52}
# created
# topic=bpm, partition=0, offset=36 : (key=None, value={'timestamp': '2019-09-21 16:32:36', 'bpm': '58', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 404193), 'bpm': 58}
# created
# topic=bpm, partition=0, offset=37 : (key=None, value={'timestamp': '2019-09-21 16:32:37', 'bpm': '65', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 408381), 'bpm': 65}
# created
# topic=bpm, partition=0, offset=38 : (key=None, value={'timestamp': '2019-09-21 16:32:37', 'bpm': '73', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 412363), 'bpm': 73}
# created
# topic=bpm, partition=0, offset=39 : (key=None, value={'timestamp': '2019-09-21 16:32:37', 'bpm': '85', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 416795), 'bpm': 85}
# created
# topic=bpm, partition=0, offset=40 : (key=None, value={'timestamp': '2019-09-21 16:32:38', 'bpm': '113', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 421251), 'bpm': 113}
# created
# topic=bpm, partition=0, offset=41 : (key=None, value={'timestamp': '2019-09-21 16:32:38', 'bpm': '139', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 425522), 'bpm': 139}
# created
# topic=bpm, partition=0, offset=42 : (key=None, value={'timestamp': '2019-09-21 16:32:38', 'bpm': '170', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 430415), 'bpm': 170}
# created
# topic=bpm, partition=0, offset=43 : (key=None, value={'timestamp': '2019-09-21 16:32:38', 'bpm': '191', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 435698), 'bpm': 191}
# created
# topic=bpm, partition=0, offset=44 : (key=None, value={'timestamp': '2019-09-21 16:32:39', 'bpm': '200', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 440251), 'bpm': 200}
# created
# topic=bpm, partition=0, offset=45 : (key=None, value={'timestamp': '2019-09-21 16:32:40', 'bpm': '167', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 444524), 'bpm': 167}
# created
# topic=bpm, partition=0, offset=46 : (key=None, value={'timestamp': '2019-09-21 16:32:40', 'bpm': '153', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 449274), 'bpm': 153}
# created
# topic=bpm, partition=0, offset=47 : (key=None, value={'timestamp': '2019-09-21 16:32:41', 'bpm': '148', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 453877), 'bpm': 148}
# created
# topic=bpm, partition=0, offset=48 : (key=None, value={'timestamp': '2019-09-21 16:32:41', 'bpm': '135', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 458510), 'bpm': 135}
# created
# topic=bpm, partition=0, offset=49 : (key=None, value={'timestamp': '2019-09-21 16:32:42', 'bpm': '129', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 462857), 'bpm': 129}
# created
# topic=bpm, partition=0, offset=50 : (key=None, value={'timestamp': '2019-09-21 16:32:42', 'bpm': '132', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 32, 45, 466752), 'bpm': 132}
# created
# topic=bpm, partition=0, offset=51 : (key=None, value={'timestamp': '2019-09-21 16:33:28', 'bpm': '74', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 28, 369907), 'bpm': 74}
# created
# topic=bpm, partition=0, offset=52 : (key=None, value={'timestamp': '2019-09-21 16:33:29', 'bpm': '69', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 29, 706261), 'bpm': 69}
# created
# topic=bpm, partition=0, offset=53 : (key=None, value={'timestamp': '2019-09-21 16:33:30', 'bpm': '69', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 30, 517323), 'bpm': 69}
# created
# topic=bpm, partition=0, offset=54 : (key=None, value={'timestamp': '2019-09-21 16:33:33', 'bpm': '194', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 33, 843138), 'bpm': 194}
# created
# topic=bpm, partition=0, offset=55 : (key=None, value={'timestamp': '2019-09-21 16:33:35', 'bpm': '142', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 35, 303040), 'bpm': 142}
# created
# topic=bpm, partition=0, offset=56 : (key=None, value={'timestamp': '2019-09-21 16:33:36', 'bpm': '125', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 36, 165630), 'bpm': 125}
# created
# topic=bpm, partition=0, offset=57 : (key=None, value={'timestamp': '2019-09-21 16:33:36', 'bpm': '113', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 36, 979483), 'bpm': 113}
# created
# topic=bpm, partition=0, offset=58 : (key=None, value={'timestamp': '2019-09-21 16:33:37', 'bpm': '109', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 37, 483061), 'bpm': 109}
# created
# topic=bpm, partition=0, offset=59 : (key=None, value={'timestamp': '2019-09-21 16:33:38', 'bpm': '102', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 38, 166850), 'bpm': 102}
# created
# topic=bpm, partition=0, offset=60 : (key=None, value={'timestamp': '2019-09-21 16:33:38', 'bpm': '94', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 38, 980395), 'bpm': 94}
# created
# topic=bpm, partition=0, offset=61 : (key=None, value={'timestamp': '2019-09-21 16:33:39', 'bpm': '87', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 39, 802250), 'bpm': 87}
# created
# topic=bpm, partition=0, offset=62 : (key=None, value={'timestamp': '2019-09-21 16:33:40', 'bpm': '80', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 40, 632529), 'bpm': 80}
# created
# topic=bpm, partition=0, offset=63 : (key=None, value={'timestamp': '2019-09-21 16:33:41', 'bpm': '75', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 41, 488940), 'bpm': 75}
# created
# topic=bpm, partition=0, offset=64 : (key=None, value={'timestamp': '2019-09-21 16:33:42', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 42, 355544), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=65 : (key=None, value={'timestamp': '2019-09-21 16:33:43', 'bpm': '75', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 43, 199446), 'bpm': 75}
# created
# topic=bpm, partition=0, offset=66 : (key=None, value={'timestamp': '2019-09-21 16:33:44', 'bpm': '75', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 44, 80874), 'bpm': 75}
# created
# topic=bpm, partition=0, offset=67 : (key=None, value={'timestamp': '2019-09-21 16:33:44', 'bpm': '75', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 44, 913536), 'bpm': 75}
# created
# topic=bpm, partition=0, offset=68 : (key=None, value={'timestamp': '2019-09-21 16:33:45', 'bpm': '72', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 45, 803565), 'bpm': 72}
# created
# topic=bpm, partition=0, offset=69 : (key=None, value={'timestamp': '2019-09-21 16:33:46', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 48, 727255), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=70 : (key=None, value={'timestamp': '2019-09-21 16:33:50', 'bpm': '68', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 50, 960971), 'bpm': 68}
# created
# topic=bpm, partition=0, offset=71 : (key=None, value={'timestamp': '2019-09-21 16:33:51', 'bpm': '68', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 51, 857014), 'bpm': 68}
# created
# topic=bpm, partition=0, offset=72 : (key=None, value={'timestamp': '2019-09-21 16:33:52', 'bpm': '68', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 52, 734246), 'bpm': 68}
# created
# topic=bpm, partition=0, offset=73 : (key=None, value={'timestamp': '2019-09-21 16:33:53', 'bpm': '68', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 53, 586649), 'bpm': 68}
# created
# topic=bpm, partition=0, offset=74 : (key=None, value={'timestamp': '2019-09-21 16:33:54', 'bpm': '68', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 54, 484654), 'bpm': 68}
# created
# topic=bpm, partition=0, offset=75 : (key=None, value={'timestamp': '2019-09-21 16:33:55', 'bpm': '68', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 55, 372738), 'bpm': 68}
# created
# topic=bpm, partition=0, offset=76 : (key=None, value={'timestamp': '2019-09-21 16:33:56', 'bpm': '68', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 56, 196171), 'bpm': 68}
# created
# topic=bpm, partition=0, offset=77 : (key=None, value={'timestamp': '2019-09-21 16:33:56', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 56, 864981), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=78 : (key=None, value={'timestamp': '2019-09-21 16:33:57', 'bpm': '73', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 57, 346024), 'bpm': 73}
# created
# topic=bpm, partition=0, offset=79 : (key=None, value={'timestamp': '2019-09-21 16:33:57', 'bpm': '77', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 57, 798345), 'bpm': 77}
# created
# topic=bpm, partition=0, offset=80 : (key=None, value={'timestamp': '2019-09-21 16:33:58', 'bpm': '79', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 58, 524492), 'bpm': 79}
# created
# topic=bpm, partition=0, offset=81 : (key=None, value={'timestamp': '2019-09-21 16:33:59', 'bpm': '81', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 33, 59, 238188), 'bpm': 81}
# created
# topic=bpm, partition=0, offset=82 : (key=None, value={'timestamp': '2019-09-21 16:34:00', 'bpm': '78', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 34, 0, 394146), 'bpm': 78}
# created
# topic=bpm, partition=0, offset=83 : (key=None, value={'timestamp': '2019-09-21 16:34:01', 'bpm': '80', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 34, 1, 121716), 'bpm': 80}
# created
# topic=bpm, partition=0, offset=84 : (key=None, value={'timestamp': '2019-09-21 16:34:45', 'bpm': '74', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 34, 45, 71871), 'bpm': 74}
# created
# topic=bpm, partition=0, offset=85 : (key=None, value={'timestamp': '2019-09-21 16:34:45', 'bpm': '77', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 34, 45, 556060), 'bpm': 77}
# created
# topic=bpm, partition=0, offset=86 : (key=None, value={'timestamp': '2019-09-21 16:35:47', 'bpm': '40', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 35, 47, 790631), 'bpm': 40}
# created
# topic=bpm, partition=0, offset=87 : (key=None, value={'timestamp': '2019-09-21 16:35:48', 'bpm': '42', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 35, 48, 729843), 'bpm': 42}
# created
# topic=bpm, partition=0, offset=88 : (key=None, value={'timestamp': '2019-09-21 16:35:49', 'bpm': '44', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 35, 49, 385089), 'bpm': 44}
# created
# topic=bpm, partition=0, offset=89 : (key=None, value={'timestamp': '2019-09-21 16:35:50', 'bpm': '46', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 35, 50, 192599), 'bpm': 46}
# created
# topic=bpm, partition=0, offset=90 : (key=None, value={'timestamp': '2019-09-21 16:35:51', 'bpm': '49', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 35, 51, 33538), 'bpm': 49}
# created
# topic=bpm, partition=0, offset=91 : (key=None, value={'timestamp': '2019-09-21 16:35:51', 'bpm': '52', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 35, 51, 921491), 'bpm': 52}
# created
# topic=bpm, partition=0, offset=92 : (key=None, value={'timestamp': '2019-09-21 16:35:52', 'bpm': '55', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 35, 52, 740887), 'bpm': 55}
# created
# topic=bpm, partition=0, offset=93 : (key=None, value={'timestamp': '2019-09-21 16:35:53', 'bpm': '58', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 35, 53, 617997), 'bpm': 58}
# created
# topic=bpm, partition=0, offset=94 : (key=None, value={'timestamp': '2019-09-21 16:35:54', 'bpm': '61', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 35, 54, 516192), 'bpm': 61}
# created
# topic=bpm, partition=0, offset=95 : (key=None, value={'timestamp': '2019-09-21 16:35:55', 'bpm': '66', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 35, 55, 391690), 'bpm': 66}
# created
# topic=bpm, partition=0, offset=96 : (key=None, value={'timestamp': '2019-09-21 16:35:56', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 35, 56, 312295), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=97 : (key=None, value={'timestamp': '2019-09-21 16:35:57', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 35, 57, 202485), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=98 : (key=None, value={'timestamp': '2019-09-21 16:35:58', 'bpm': '69', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 35, 58, 62584), 'bpm': 69}
# created
# topic=bpm, partition=0, offset=99 : (key=None, value={'timestamp': '2019-09-21 16:35:58', 'bpm': '68', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 35, 58, 937832), 'bpm': 68}
# created
# topic=bpm, partition=0, offset=100 : (key=None, value={'timestamp': '2019-09-21 16:35:59', 'bpm': '68', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 35, 59, 860374), 'bpm': 68}
# created
# topic=bpm, partition=0, offset=101 : (key=None, value={'timestamp': '2019-09-21 16:36:00', 'bpm': '68', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 0, 621847), 'bpm': 68}
# created
# topic=bpm, partition=0, offset=102 : (key=None, value={'timestamp': '2019-09-21 16:36:01', 'bpm': '68', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 1, 462030), 'bpm': 68}
# created
# topic=bpm, partition=0, offset=103 : (key=None, value={'timestamp': '2019-09-21 16:36:02', 'bpm': '68', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 2, 321495), 'bpm': 68}
# created
# topic=bpm, partition=0, offset=104 : (key=None, value={'timestamp': '2019-09-21 16:36:03', 'bpm': '69', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 3, 189460), 'bpm': 69}
# created
# topic=bpm, partition=0, offset=105 : (key=None, value={'timestamp': '2019-09-21 16:36:03', 'bpm': '69', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 3, 998592), 'bpm': 69}
# created
# topic=bpm, partition=0, offset=106 : (key=None, value={'timestamp': '2019-09-21 16:36:04', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 4, 857278), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=107 : (key=None, value={'timestamp': '2019-09-21 16:36:05', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 5, 768716), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=108 : (key=None, value={'timestamp': '2019-09-21 16:36:06', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 6, 622068), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=109 : (key=None, value={'timestamp': '2019-09-21 16:36:07', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 7, 450466), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=110 : (key=None, value={'timestamp': '2019-09-21 16:36:08', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 8, 319493), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=111 : (key=None, value={'timestamp': '2019-09-21 16:36:09', 'bpm': '69', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 9, 207312), 'bpm': 69}
# created
# topic=bpm, partition=0, offset=112 : (key=None, value={'timestamp': '2019-09-21 16:36:10', 'bpm': '69', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 10, 63199), 'bpm': 69}
# created
# topic=bpm, partition=0, offset=113 : (key=None, value={'timestamp': '2019-09-21 16:36:10', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 10, 866940), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=114 : (key=None, value={'timestamp': '2019-09-21 16:36:11', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 11, 668059), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=115 : (key=None, value={'timestamp': '2019-09-21 16:36:12', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 12, 527725), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=116 : (key=None, value={'timestamp': '2019-09-21 16:36:13', 'bpm': '71', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 13, 312997), 'bpm': 71}
# created
# topic=bpm, partition=0, offset=117 : (key=None, value={'timestamp': '2019-09-21 16:36:14', 'bpm': '72', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 14, 128128), 'bpm': 72}
# created
# topic=bpm, partition=0, offset=118 : (key=None, value={'timestamp': '2019-09-21 16:36:14', 'bpm': '72', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 14, 910313), 'bpm': 72}
# created
# topic=bpm, partition=0, offset=119 : (key=None, value={'timestamp': '2019-09-21 16:36:15', 'bpm': '71', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 15, 795864), 'bpm': 71}
# created
# topic=bpm, partition=0, offset=120 : (key=None, value={'timestamp': '2019-09-21 16:36:16', 'bpm': '71', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 16, 660455), 'bpm': 71}
# created
# topic=bpm, partition=0, offset=121 : (key=None, value={'timestamp': '2019-09-21 16:36:17', 'bpm': '72', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 17, 480332), 'bpm': 72}
# created
# topic=bpm, partition=0, offset=122 : (key=None, value={'timestamp': '2019-09-21 16:36:18', 'bpm': '72', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 18, 346535), 'bpm': 72}
# created
# topic=bpm, partition=0, offset=123 : (key=None, value={'timestamp': '2019-09-21 16:36:19', 'bpm': '71', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 19, 247794), 'bpm': 71}
# created
# topic=bpm, partition=0, offset=124 : (key=None, value={'timestamp': '2019-09-21 16:36:20', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 20, 195319), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=125 : (key=None, value={'timestamp': '2019-09-21 16:36:20', 'bpm': '71', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 20, 894072), 'bpm': 71}
# created
# topic=bpm, partition=0, offset=126 : (key=None, value={'timestamp': '2019-09-21 16:36:21', 'bpm': '71', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 21, 732760), 'bpm': 71}
# created
# topic=bpm, partition=0, offset=127 : (key=None, value={'timestamp': '2019-09-21 16:36:22', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 22, 572400), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=128 : (key=None, value={'timestamp': '2019-09-21 16:36:23', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 23, 479856), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=129 : (key=None, value={'timestamp': '2019-09-21 16:36:24', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 24, 264310), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=130 : (key=None, value={'timestamp': '2019-09-21 16:36:25', 'bpm': '71', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 25, 118540), 'bpm': 71}
# created
# topic=bpm, partition=0, offset=131 : (key=None, value={'timestamp': '2019-09-21 16:36:25', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 25, 973668), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=132 : (key=None, value={'timestamp': '2019-09-21 16:36:26', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 26, 841521), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=133 : (key=None, value={'timestamp': '2019-09-21 16:36:27', 'bpm': '71', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 27, 642253), 'bpm': 71}
# created
# topic=bpm, partition=0, offset=134 : (key=None, value={'timestamp': '2019-09-21 16:36:28', 'bpm': '71', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 28, 490032), 'bpm': 71}
# created
# topic=bpm, partition=0, offset=135 : (key=None, value={'timestamp': '2019-09-21 16:36:29', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 29, 365318), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=136 : (key=None, value={'timestamp': '2019-09-21 16:36:30', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 30, 223942), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=137 : (key=None, value={'timestamp': '2019-09-21 16:36:31', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 31, 72382), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=138 : (key=None, value={'timestamp': '2019-09-21 16:36:31', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 31, 968835), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=139 : (key=None, value={'timestamp': '2019-09-21 16:36:32', 'bpm': '70', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 32, 808563), 'bpm': 70}
# created
# topic=bpm, partition=0, offset=140 : (key=None, value={'timestamp': '2019-09-21 16:36:33', 'bpm': '72', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 33, 335585), 'bpm': 72}
# created
# topic=bpm, partition=0, offset=141 : (key=None, value={'timestamp': '2019-09-21 16:36:35', 'bpm': '64', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 35, 287332), 'bpm': 64}
# created
# topic=bpm, partition=0, offset=142 : (key=None, value={'timestamp': '2019-09-21 16:36:42', 'bpm': '53', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 42, 584138), 'bpm': 53}
# created
# topic=bpm, partition=0, offset=143 : (key=None, value={'timestamp': '2019-09-21 16:36:43', 'bpm': '55', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 43, 250064), 'bpm': 55}
# created
# topic=bpm, partition=0, offset=144 : (key=None, value={'timestamp': '2019-09-21 16:36:45', 'bpm': '51', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 45, 196611), 'bpm': 51}
# created
# topic=bpm, partition=0, offset=145 : (key=None, value={'timestamp': '2019-09-21 16:36:46', 'bpm': '51', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 46, 372736), 'bpm': 51}
# created
# topic=bpm, partition=0, offset=146 : (key=None, value={'timestamp': '2019-09-21 16:36:47', 'bpm': '52', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 47, 277053), 'bpm': 52}
# created
# topic=bpm, partition=0, offset=147 : (key=None, value={'timestamp': '2019-09-21 16:36:47', 'bpm': '55', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 47, 884893), 'bpm': 55}
# created
# topic=bpm, partition=0, offset=148 : (key=None, value={'timestamp': '2019-09-21 16:36:48', 'bpm': '54', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 49, 7025), 'bpm': 54}
# created
# topic=bpm, partition=0, offset=149 : (key=None, value={'timestamp': '2019-09-21 16:36:49', 'bpm': '57', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 49, 704108), 'bpm': 57}
# created
# topic=bpm, partition=0, offset=150 : (key=None, value={'timestamp': '2019-09-21 16:36:50', 'bpm': '60', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 50, 265979), 'bpm': 60}
# created
# topic=bpm, partition=0, offset=151 : (key=None, value={'timestamp': '2019-09-21 16:36:50', 'bpm': '64', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 50, 762839), 'bpm': 64}
# created
# topic=bpm, partition=0, offset=152 : (key=None, value={'timestamp': '2019-09-21 16:36:51', 'bpm': '67', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 51, 501918), 'bpm': 67}
# created
# topic=bpm, partition=0, offset=153 : (key=None, value={'timestamp': '2019-09-21 16:36:52', 'bpm': '67', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 52, 134417), 'bpm': 67}
# created
# topic=bpm, partition=0, offset=154 : (key=None, value={'timestamp': '2019-09-21 16:36:52', 'bpm': '78', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 52, 805926), 'bpm': 78}
# created
# topic=bpm, partition=0, offset=155 : (key=None, value={'timestamp': '2019-09-21 16:36:53', 'bpm': '84', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 53, 493941), 'bpm': 84}
# created
# topic=bpm, partition=0, offset=156 : (key=None, value={'timestamp': '2019-09-21 16:36:54', 'bpm': '86', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 54, 214466), 'bpm': 86}
# created
# topic=bpm, partition=0, offset=157 : (key=None, value={'timestamp': '2019-09-21 16:36:54', 'bpm': '84', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 54, 928713), 'bpm': 84}
# created
# topic=bpm, partition=0, offset=158 : (key=None, value={'timestamp': '2019-09-21 16:36:55', 'bpm': '89', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 55, 682851), 'bpm': 89}
# created
# topic=bpm, partition=0, offset=159 : (key=None, value={'timestamp': '2019-09-21 16:36:56', 'bpm': '93', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 56, 136045), 'bpm': 93}
# created
# topic=bpm, partition=0, offset=160 : (key=None, value={'timestamp': '2019-09-21 16:36:57', 'bpm': '77', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 36, 57, 993290), 'bpm': 77}
# created
# topic=bpm, partition=0, offset=161 : (key=None, value={'timestamp': '2019-09-21 16:38:11', 'bpm': '37', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 38, 11, 605327), 'bpm': 37}
# created
# topic=bpm, partition=0, offset=162 : (key=None, value={'timestamp': '2019-09-21 16:38:12', 'bpm': '39', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 38, 12, 556002), 'bpm': 39}
# created
# topic=bpm, partition=0, offset=163 : (key=None, value={'timestamp': '2019-09-21 16:38:14', 'bpm': '37', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 38, 14, 740730), 'bpm': 37}
# created
# topic=bpm, partition=0, offset=164 : (key=None, value={'timestamp': '2019-09-21 16:38:16', 'bpm': '38', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 38, 16, 64101), 'bpm': 38}
# created
# topic=bpm, partition=0, offset=165 : (key=None, value={'timestamp': '2019-09-21 16:38:17', 'bpm': '37', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 38, 18, 55620), 'bpm': 37}
# created
# topic=bpm, partition=0, offset=166 : (key=None, value={'timestamp': '2019-09-21 16:38:19', 'bpm': '38', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 38, 19, 190885), 'bpm': 38}
# created
# topic=bpm, partition=0, offset=167 : (key=None, value={'timestamp': '2019-09-21 16:38:21', 'bpm': '37', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 38, 24, 106513), 'bpm': 37}
# created
# topic=bpm, partition=0, offset=168 : (key=None, value={'timestamp': '2019-09-21 16:38:34', 'bpm': '40', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 38, 35, 19012), 'bpm': 40}
# created
# topic=bpm, partition=0, offset=169 : (key=None, value={'timestamp': '2019-09-21 16:38:36', 'bpm': '40', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 38, 36, 467837), 'bpm': 40}
# created
# topic=bpm, partition=0, offset=170 : (key=None, value={'timestamp': '2019-09-21 16:38:41', 'bpm': '27', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 38, 42, 26577), 'bpm': 27}
# created
# topic=bpm, partition=0, offset=171 : (key=None, value={'timestamp': '2019-09-21 16:38:43', 'bpm': '28', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 38, 43, 357309), 'bpm': 28}
# created
# topic=bpm, partition=0, offset=172 : (key=None, value={'timestamp': '2019-09-21 16:38:45', 'bpm': '28', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 38, 45, 75792), 'bpm': 28}
# created
# topic=bpm, partition=0, offset=173 : (key=None, value={'timestamp': '2019-09-21 16:38:52', 'bpm': '52', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 38, 52, 281232), 'bpm': 52}
# created
# topic=bpm, partition=0, offset=174 : (key=None, value={'timestamp': '2019-09-21 16:39:00', 'bpm': '57', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 39, 0, 730639), 'bpm': 57}
# created
# topic=bpm, partition=0, offset=175 : (key=None, value={'timestamp': '2019-09-21 16:39:19', 'bpm': '106', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 39, 19, 997499), 'bpm': 106}
# created
# topic=bpm, partition=0, offset=176 : (key=None, value={'timestamp': '2019-09-21 16:39:22', 'bpm': '79', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 39, 22, 424281), 'bpm': 79}
# created
# topic=bpm, partition=0, offset=177 : (key=None, value={'timestamp': '2019-09-21 16:39:23', 'bpm': '71', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 39, 23, 888873), 'bpm': 71}
# created
# topic=bpm, partition=0, offset=178 : (key=None, value={'timestamp': '2019-09-21 16:39:44', 'bpm': '49', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 39, 44, 951634), 'bpm': 49}
# created
# topic=bpm, partition=0, offset=179 : (key=None, value={'timestamp': '2019-09-21 16:39:52', 'bpm': '44', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 39, 52, 45687), 'bpm': 44}
# created
# topic=bpm, partition=0, offset=180 : (key=None, value={'timestamp': '2019-09-21 16:39:53', 'bpm': '43', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 39, 53, 907469), 'bpm': 43}
# created
# topic=bpm, partition=0, offset=181 : (key=None, value={'timestamp': '2019-09-21 16:39:55', 'bpm': '43', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 39, 55, 41085), 'bpm': 43}
# created
# topic=bpm, partition=0, offset=182 : (key=None, value={'timestamp': '2019-09-21 16:39:56', 'bpm': '43', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 39, 56, 312125), 'bpm': 43}
# created
# topic=bpm, partition=0, offset=183 : (key=None, value={'timestamp': '2019-09-21 16:39:57', 'bpm': '45', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 39, 57, 162131), 'bpm': 45}
# created
# topic=bpm, partition=0, offset=184 : (key=None, value={'timestamp': '2019-09-21 16:39:57', 'bpm': '47', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 39, 57, 940770), 'bpm': 47}
# created
# topic=bpm, partition=0, offset=185 : (key=None, value={'timestamp': '2019-09-21 16:39:58', 'bpm': '49', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 39, 58, 749827), 'bpm': 49}
# created
# topic=bpm, partition=0, offset=186 : (key=None, value={'timestamp': '2019-09-21 16:39:59', 'bpm': '51', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 39, 59, 597141), 'bpm': 51}
# created
# topic=bpm, partition=0, offset=187 : (key=None, value={'timestamp': '2019-09-21 16:40:00', 'bpm': '54', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 40, 0, 432976), 'bpm': 54}
# created
# topic=bpm, partition=0, offset=188 : (key=None, value={'timestamp': '2019-09-21 16:40:01', 'bpm': '56', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 40, 1, 243729), 'bpm': 56}
# created
# topic=bpm, partition=0, offset=189 : (key=None, value={'timestamp': '2019-09-21 16:40:02', 'bpm': '59', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 40, 2, 52406), 'bpm': 59}
# created
# topic=bpm, partition=0, offset=190 : (key=None, value={'timestamp': '2019-09-21 16:40:02', 'bpm': '67', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 40, 2, 842182), 'bpm': 67}
# created
# topic=bpm, partition=0, offset=191 : (key=None, value={'timestamp': '2019-09-21 16:40:03', 'bpm': '69', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 40, 3, 646221), 'bpm': 69}
# created
# topic=bpm, partition=0, offset=192 : (key=None, value={'timestamp': '2019-09-21 16:40:04', 'bpm': '73', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 40, 4, 443545), 'bpm': 73}
# created
# topic=bpm, partition=0, offset=193 : (key=None, value={'timestamp': '2019-09-21 16:40:05', 'bpm': '73', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 40, 5, 295720), 'bpm': 73}
# created
# topic=bpm, partition=0, offset=194 : (key=None, value={'timestamp': '2019-09-21 16:40:06', 'bpm': '74', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 40, 6, 42252), 'bpm': 74}
# created
# topic=bpm, partition=0, offset=195 : (key=None, value={'timestamp': '2019-09-21 16:40:06', 'bpm': '74', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 40, 6, 827514), 'bpm': 74}
# created
# topic=bpm, partition=0, offset=196 : (key=None, value={'timestamp': '2019-09-21 16:40:07', 'bpm': '74', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 40, 7, 632898), 'bpm': 74}
# created
# topic=bpm, partition=0, offset=197 : (key=None, value={'timestamp': '2019-09-21 16:40:08', 'bpm': '75', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 40, 8, 642776), 'bpm': 75}
# created
# topic=bpm, partition=0, offset=198 : (key=None, value={'timestamp': '2019-09-21 16:40:09', 'bpm': '75', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 40, 9, 159891), 'bpm': 75}
# created
# topic=bpm, partition=0, offset=199 : (key=None, value={'timestamp': '2019-09-21 16:40:09', 'bpm': '75', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 40, 9, 991998), 'bpm': 75}
# created
# topic=bpm, partition=0, offset=200 : (key=None, value={'timestamp': '2019-09-21 16:40:10', 'bpm': '75', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 40, 10, 817704), 'bpm': 75}
# created
# ...
# created
# topic=bpm, partition=0, offset=304 : (key=None, value={'timestamp': '2019-09-21 16:41:56', 'bpm': '79', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 41, 56, 733597), 'bpm': 79}
# created
# topic=bpm, partition=0, offset=305 : (key=None, value={'timestamp': '2019-09-21 16:41:57', 'bpm': '81', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 41, 57, 483804), 'bpm': 81}
# created
# topic=bpm, partition=0, offset=306 : (key=None, value={'timestamp': '2019-09-21 16:42:02', 'bpm': '29', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 2, 503681), 'bpm': 29}
# created
# topic=bpm, partition=0, offset=307 : (key=None, value={'timestamp': '2019-09-21 16:42:03', 'bpm': '30', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 3, 729521), 'bpm': 30}
# created
# topic=bpm, partition=0, offset=308 : (key=None, value={'timestamp': '2019-09-21 16:42:04', 'bpm': '32', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 4, 574420), 'bpm': 32}
# created
# topic=bpm, partition=0, offset=309 : (key=None, value={'timestamp': '2019-09-21 16:42:06', 'bpm': '33', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 6, 192137), 'bpm': 33}
# created
# topic=bpm, partition=0, offset=310 : (key=None, value={'timestamp': '2019-09-21 16:42:07', 'bpm': '35', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 7, 139431), 'bpm': 35}
# created
# topic=bpm, partition=0, offset=311 : (key=None, value={'timestamp': '2019-09-21 16:42:08', 'bpm': '36', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 8, 822015), 'bpm': 36}
# created
# topic=bpm, partition=0, offset=312 : (key=None, value={'timestamp': '2019-09-21 16:42:09', 'bpm': '38', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 9, 875033), 'bpm': 38}
# created
# topic=bpm, partition=0, offset=313 : (key=None, value={'timestamp': '2019-09-21 16:42:10', 'bpm': '42', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 10, 513928), 'bpm': 42}
# created
# topic=bpm, partition=0, offset=314 : (key=None, value={'timestamp': '2019-09-21 16:42:12', 'bpm': '42', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 12, 552997), 'bpm': 42}
# created
# topic=bpm, partition=0, offset=315 : (key=None, value={'timestamp': '2019-09-21 16:42:13', 'bpm': '44', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 13, 997086), 'bpm': 44}
# created
# topic=bpm, partition=0, offset=316 : (key=None, value={'timestamp': '2019-09-21 16:42:15', 'bpm': '46', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 15, 497589), 'bpm': 46}
# created
# topic=bpm, partition=0, offset=317 : (key=None, value={'timestamp': '2019-09-21 16:42:16', 'bpm': '47', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 16, 426100), 'bpm': 47}
# created
# topic=bpm, partition=0, offset=318 : (key=None, value={'timestamp': '2019-09-21 16:42:17', 'bpm': '46', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 17, 478743), 'bpm': 46}
# created
# topic=bpm, partition=0, offset=319 : (key=None, value={'timestamp': '2019-09-21 16:42:18', 'bpm': '50', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 18, 104322), 'bpm': 50}
# created
# topic=bpm, partition=0, offset=320 : (key=None, value={'timestamp': '2019-09-21 16:42:19', 'bpm': '47', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 19, 779161), 'bpm': 47}
# created
# topic=bpm, partition=0, offset=321 : (key=None, value={'timestamp': '2019-09-21 16:42:31', 'bpm': '60', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 31, 586103), 'bpm': 60}
# created
# topic=bpm, partition=0, offset=322 : (key=None, value={'timestamp': '2019-09-21 16:42:32', 'bpm': '59', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 32, 705451), 'bpm': 59}
# created
# topic=bpm, partition=0, offset=323 : (key=None, value={'timestamp': '2019-09-21 16:42:36', 'bpm': '66', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 36, 783779), 'bpm': 66}
# created
# topic=bpm, partition=0, offset=324 : (key=None, value={'timestamp': '2019-09-21 16:42:37', 'bpm': '68', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 37, 355118), 'bpm': 68}
# created
# topic=bpm, partition=0, offset=325 : (key=None, value={'timestamp': '2019-09-21 16:42:38', 'bpm': '63', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 39, 2995), 'bpm': 63}
# created
# topic=bpm, partition=0, offset=326 : (key=None, value={'timestamp': '2019-09-21 16:42:40', 'bpm': '59', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 40, 535737), 'bpm': 59}
# created
# topic=bpm, partition=0, offset=327 : (key=None, value={'timestamp': '2019-09-21 16:42:41', 'bpm': '59', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 41, 469405), 'bpm': 59}
# created
# topic=bpm, partition=0, offset=328 : (key=None, value={'timestamp': '2019-09-21 16:42:42', 'bpm': '61', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 42, 59794), 'bpm': 61}
# created
# topic=bpm, partition=0, offset=329 : (key=None, value={'timestamp': '2019-09-21 16:42:42', 'bpm': '63', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 42, 587464), 'bpm': 63}
# created
# topic=bpm, partition=0, offset=330 : (key=None, value={'timestamp': '2019-09-21 16:42:43', 'bpm': '63', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 43, 445895), 'bpm': 63}
# created
# topic=bpm, partition=0, offset=331 : (key=None, value={'timestamp': '2019-09-21 16:42:43', 'bpm': '66', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 43, 975749), 'bpm': 66}
# created
# topic=bpm, partition=0, offset=332 : (key=None, value={'timestamp': '2019-09-21 16:42:44', 'bpm': '71', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 44, 303291), 'bpm': 71}
# created
# topic=bpm, partition=0, offset=333 : (key=None, value={'timestamp': '2019-09-21 16:42:44', 'bpm': '75', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 44, 759278), 'bpm': 75}
# created
# topic=bpm, partition=0, offset=334 : (key=None, value={'timestamp': '2019-09-21 16:42:45', 'bpm': '78', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 45, 32531), 'bpm': 78}
# created
# topic=bpm, partition=0, offset=335 : (key=None, value={'timestamp': '2019-09-21 16:42:46', 'bpm': '75', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 46, 997882), 'bpm': 75}
# created
# topic=bpm, partition=0, offset=336 : (key=None, value={'timestamp': '2019-09-21 16:42:48', 'bpm': '77', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 48, 254296), 'bpm': 77}
# created
# topic=bpm, partition=0, offset=337 : (key=None, value={'timestamp': '2019-09-21 16:42:49', 'bpm': '75', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 49, 411051), 'bpm': 75}
# created
# topic=bpm, partition=0, offset=338 : (key=None, value={'timestamp': '2019-09-21 16:42:50', 'bpm': '67', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 50, 939151), 'bpm': 67}
# created
# topic=bpm, partition=0, offset=339 : (key=None, value={'timestamp': '2019-09-21 16:42:51', 'bpm': '63', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 52, 57147), 'bpm': 63}
# created
# topic=bpm, partition=0, offset=340 : (key=None, value={'timestamp': '2019-09-21 16:42:53', 'bpm': '59', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 53, 478793), 'bpm': 59}
# created
# topic=bpm, partition=0, offset=341 : (key=None, value={'timestamp': '2019-09-21 16:42:54', 'bpm': '57', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 54, 363718), 'bpm': 57}
# created
# topic=bpm, partition=0, offset=342 : (key=None, value={'timestamp': '2019-09-21 16:42:55', 'bpm': '55', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 55, 133326), 'bpm': 55}
# created
# topic=bpm, partition=0, offset=343 : (key=None, value={'timestamp': '2019-09-21 16:42:55', 'bpm': '55', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 55, 632623), 'bpm': 55}
# created
# topic=bpm, partition=0, offset=344 : (key=None, value={'timestamp': '2019-09-21 16:42:57', 'bpm': '47', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 57, 575002), 'bpm': 47}
# created
# topic=bpm, partition=0, offset=345 : (key=None, value={'timestamp': '2019-09-21 16:42:58', 'bpm': '51', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 58, 718981), 'bpm': 51}
# created
# topic=bpm, partition=0, offset=346 : (key=None, value={'timestamp': '2019-09-21 16:42:59', 'bpm': '51', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 42, 59, 980200), 'bpm': 51}
# created
# topic=bpm, partition=0, offset=347 : (key=None, value={'timestamp': '2019-09-21 16:43:01', 'bpm': '49', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 43, 1, 585986), 'bpm': 49}
# created
# topic=bpm, partition=0, offset=348 : (key=None, value={'timestamp': '2019-09-21 16:43:02', 'bpm': '51', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 43, 2, 612422), 'bpm': 51}
# created
# topic=bpm, partition=0, offset=349 : (key=None, value={'timestamp': '2019-09-21 16:43:03', 'bpm': '51', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 43, 3, 587538), 'bpm': 51}
# created
# topic=bpm, partition=0, offset=350 : (key=None, value={'timestamp': '2019-09-21 16:43:10', 'bpm': '50', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 43, 10, 815201), 'bpm': 50}
# created
# topic=bpm, partition=0, offset=351 : (key=None, value={'timestamp': '2019-09-21 16:43:11', 'bpm': '53', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 43, 11, 524175), 'bpm': 53}
# created
# topic=bpm, partition=0, offset=352 : (key=None, value={'timestamp': '2019-09-21 16:43:13', 'bpm': '48', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 43, 13, 660782), 'bpm': 48}
# created
# topic=bpm, partition=0, offset=353 : (key=None, value={'timestamp': '2019-09-21 16:43:14', 'bpm': '48', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 43, 14, 947111), 'bpm': 48}
# created
# topic=bpm, partition=0, offset=354 : (key=None, value={'timestamp': '2019-09-21 16:43:26', 'bpm': '41', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 43, 26, 306862), 'bpm': 41}
# created
# topic=bpm, partition=0, offset=355 : (key=None, value={'timestamp': '2019-09-21 16:43:35', 'bpm': '150', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 43, 35, 722707), 'bpm': 150}
# created
# topic=bpm, partition=0, offset=356 : (key=None, value={'timestamp': '2019-09-21 16:43:38', 'bpm': '101', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 43, 38, 78226), 'bpm': 101}
# created
# topic=bpm, partition=0, offset=357 : (key=None, value={'timestamp': '2019-09-21 16:43:39', 'bpm': '86', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 43, 39, 486358), 'bpm': 86}
# created
# topic=bpm, partition=0, offset=358 : (key=None, value={'timestamp': '2019-09-21 16:43:43', 'bpm': '52', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 43, 43, 990342), 'bpm': 52}
# created
# topic=bpm, partition=0, offset=359 : (key=None, value={'timestamp': '2019-09-21 16:43:45', 'bpm': '50', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 43, 45, 611922), 'bpm': 50}
# created
# topic=bpm, partition=0, offset=360 : (key=None, value={'timestamp': '2019-09-21 16:43:46', 'bpm': '51', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 43, 46, 570150), 'bpm': 51}
# created
# topic=bpm, partition=0, offset=361 : (key=None, value={'timestamp': '2019-09-21 16:43:53', 'bpm': '36', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 43, 53, 782263), 'bpm': 36}
# created
# topic=bpm, partition=0, offset=362 : (key=None, value={'timestamp': '2019-09-21 16:43:55', 'bpm': '36', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 43, 55, 413914), 'bpm': 36}
# created
# topic=bpm, partition=0, offset=363 : (key=None, value={'timestamp': '2019-09-21 16:43:56', 'bpm': '38', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 43, 56, 395853), 'bpm': 38}
# created
# topic=bpm, partition=0, offset=364 : (key=None, value={'timestamp': '2019-09-21 16:43:57', 'bpm': '41', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 43, 57, 26159), 'bpm': 41}
# created
# topic=bpm, partition=0, offset=365 : (key=None, value={'timestamp': '2019-09-21 16:43:57', 'bpm': '44', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 43, 57, 674178), 'bpm': 44}
# created
# topic=bpm, partition=0, offset=366 : (key=None, value={'timestamp': '2019-09-21 16:43:58', 'bpm': '45', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 43, 58, 727026), 'bpm': 45}
# created
# topic=bpm, partition=0, offset=367 : (key=None, value={'timestamp': '2019-09-21 16:43:59', 'bpm': '49', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 43, 59, 362376), 'bpm': 49}
# created
# topic=bpm, partition=0, offset=368 : (key=None, value={'timestamp': '2019-09-21 16:44:00', 'bpm': '52', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 44, 0, 465124), 'bpm': 52}
# created
# topic=bpm, partition=0, offset=369 : (key=None, value={'timestamp': '2019-09-21 16:44:01', 'bpm': '57', 'device_id': 'jimmy'})
# json= {'device_id': 'jimmy', 'timestamp': datetime.datetime(2019, 9, 21, 8, 44, 1, 38751), 'bpm': 57}
# created
# type ==> <class 'KeyboardInterrupt'>
# value ==>
# traceback ==> file name: <ipython-input-5-15d69b73daf0>
# traceback ==> line no: 43
# traceback ==> function name: <module>

# %%
print(datetime.datetime.now())
# Out:
# 2019-09-21 08:10:41.544339
