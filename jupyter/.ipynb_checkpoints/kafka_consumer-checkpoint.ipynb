# %%
from kafka import KafkaConsumer
import sys, json, pymysql, pymongo

if __name__ == "__main__":

    # 與 MongoDB連線
    client = pymongo.MongoClient(host="mongodb", port=27017)
    # 指定為 test 資料庫
    db = client.test
    # 指定 temp_humidity 集合, MongoDB的每個資料庫又包含許多集合(collection), 類似於關聯性資料庫中的表
    collection = db.temp_humidity

    # 設定要連線到Kafka集群的相關設定, 產生一個Kafka的Consumer的實例
    consumer = KafkaConsumer(
        # 指定Kafka集群伺服器
        bootstrap_servers=["kafka:9092"],
        # ConsumerGroup的名稱, 可以不指定
        #group_id="cg_001",
        # 指定msgKey的反序列化器, 若Key為None, 無法反序列化
        # key_deserializer=bytes.decode,
        # 指定msgValue的反序列化器
        #value_deserializer=bytes.decode,
        value_deserializer=lambda m: json.loads(m.decode('ascii')),
        # 是否從這個ConsumerGroup尚未讀取的partition / offset開始讀
        auto_offset_reset="earliest",
    )
   
    # 讓Consumer向Kafka集群訂閱指定的topic
    consumer.subscribe(topics="TEMP_HUMIDITY_ENRICHED")
    
    # 持續的拉取Kafka有進來的訊息
    try:
        print("Now listening for incoming messages ...")
        # 持續監控是否有新的record進來
        for record in consumer:
            topic = record.topic
            partition = record.partition
            offset = record.offset
            timestamp = record.timestamp
            # 取出msgKey與msgValue
            msgKey = record.key
            msgValue = record.value
            # 秀出metadata與msgKey & msgValue訊息
            print("topic=%s, partition=%s, offset=%s : (key=%s, value=%s)" % (record.topic, record.partition, 
                                                                              record.offset, record.key, record.value))
            j = {"device_id": msgValue["T_DEVICE_ID"], "timestamp": msgValue["T_TIMESTAMP"], 
                  "temperature": msgValue["TEMPERATURE"], "humidity": msgValue["HUMIDITY"], "rd": msgValue["T_RD"]}
            print("json=",  j)
            
            # 將資料存入 mongodb
            # 存入單筆
            result = collection.insert_one(j)
            # 存入多筆
            #result = collection.insert_many()
            print(result)

    except:
        # 錯誤處理
        e_type, e_value, e_traceback = sys.exc_info()
        print("type ==> %s" % (e_type))
        print("value ==> %s" % (e_value))
        print("traceback ==> file name: %s" % (e_traceback.tb_frame.f_code.co_filename))
        print("traceback ==> line no: %s" % (e_traceback.tb_lineno))
        print("traceback ==> function name: %s" % (e_traceback.tb_frame.f_code.co_name))
    finally:
        consumer.close()
# Out:
# Now listening for incoming messages ...
# topic=TEMP_HUMIDITY_ENRICHED, partition=0, offset=0 : (key=b'0.1774516791151951', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:01:58', 'TEMPERATURE': 29.88, 'HUMIDITY': 100, 'T_RD': '0.1774516791151951'})
# json= {'device_id': '001', 'timestamp': '2019-09-19 08:01:58', 'temperature': 29.88, 'humidity': 100, 'rd': '0.1774516791151951'}
# <pymongo.results.InsertOneResult object at 0x7fb860394888>
# topic=TEMP_HUMIDITY_ENRICHED, partition=0, offset=1 : (key=b'0.07274631587036307', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:02:00', 'TEMPERATURE': 29.32, 'HUMIDITY': 63, 'T_RD': '0.07274631587036307'})
# json= {'device_id': '001', 'timestamp': '2019-09-19 08:02:00', 'temperature': 29.32, 'humidity': 63, 'rd': '0.07274631587036307'}
# <pymongo.results.InsertOneResult object at 0x7fb860394988>
# topic=TEMP_HUMIDITY_ENRICHED, partition=0, offset=2 : (key=b'0.6662571651231061', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:02:02', 'TEMPERATURE': 29.47, 'HUMIDITY': 88, 'T_RD': '0.6662571651231061'})
# json= {'device_id': '001', 'timestamp': '2019-09-19 08:02:02', 'temperature': 29.47, 'humidity': 88, 'rd': '0.6662571651231061'}
# <pymongo.results.InsertOneResult object at 0x7fb860394b08>
# topic=TEMP_HUMIDITY_ENRICHED, partition=1, offset=0 : (key=b'0.17601699138702842', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:01:55', 'TEMPERATURE': 20.26, 'HUMIDITY': 9, 'T_RD': '0.17601699138702842'})
# json= {'device_id': '001', 'timestamp': '2019-09-19 08:01:55', 'temperature': 20.26, 'humidity': 9, 'rd': '0.17601699138702842'}
# <pymongo.results.InsertOneResult object at 0x7fb860392d88>
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=0 : (key=b'0.14562536344048926', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:02:05', 'TEMPERATURE': 27.67, 'HUMIDITY': 26, 'T_RD': '0.14562536344048926'})
# json= {'device_id': '001', 'timestamp': '2019-09-19 08:02:05', 'temperature': 27.67, 'humidity': 26, 'rd': '0.14562536344048926'}
# <pymongo.results.InsertOneResult object at 0x7fb860392d48>
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=1 : (key=b'0.9677200796285044', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:02:07', 'TEMPERATURE': 25.2, 'HUMIDITY': 90, 'T_RD': '0.9677200796285044'})
# json= {'device_id': '001', 'timestamp': '2019-09-19 08:02:07', 'temperature': 25.2, 'humidity': 90, 'rd': '0.9677200796285044'}
# <pymongo.results.InsertOneResult object at 0x7fb860392cc8>
# type ==> <class 'KeyboardInterrupt'>
# value ==>
# traceback ==> file name: <ipython-input-3-5c6cd2714187>
# traceback ==> line no: 35
# traceback ==> function name: <module>

# %%
from kafka import KafkaConsumer
import sys, json, pymysql, pymongo
from elasticsearch import Elasticsearch
from elasticsearch import helpers
import time

if __name__ == "__main__":

    # 與 MongoDB連線
    #client = pymongo.MongoClient(host="mongodb", port=27017)
    # 指定為 test 資料庫
    #db = client.test
    # 指定 temp_humidity 集合, MongoDB的每個資料庫又包含許多集合(collection), 類似於關聯性資料庫中的表
    #collection = db.temp_humidity

    # 設定要連線到Kafka集群的相關設定, 產生一個Kafka的Consumer的實例
    consumer = KafkaConsumer(
        # 指定Kafka集群伺服器
        bootstrap_servers=["kafka:9092"],
        # ConsumerGroup的名稱, 可以不指定
        #group_id="cg_001",
        # 指定msgKey的反序列化器, 若Key為None, 無法反序列化
        # key_deserializer=bytes.decode,
        # 指定msgValue的反序列化器
        #value_deserializer=bytes.decode,
        value_deserializer=lambda m: json.loads(m.decode('ascii')),
        # 是否從這個ConsumerGroup尚未讀取的partition / offset開始讀
        auto_offset_reset="earliest",
    )
   
    # 讓Consumer向Kafka集群訂閱指定的topic
    consumer.subscribe(topics="TEMP_HUMIDITY_ENRICHED")
    
    es = Elasticsearch('http://elasticsearch:9200')
    
    
    # 持續的拉取Kafka有進來的訊息
    try:
        print("Now listening for incoming messages ...")
        # 持續監控是否有新的record進來
        for record in consumer:
            topic = record.topic
            partition = record.partition
            offset = record.offset
            timestamp = record.timestamp
            # 取出msgKey與msgValue
            msgKey = record.key
            msgValue = record.value
            # 秀出metadata與msgKey & msgValue訊息
            print("topic=%s, partition=%s, offset=%s : (key=%s, value=%s)" % (record.topic, record.partition, 
                                                                              record.offset, record.key, record.value))
            j = {"device_id": msgValue["T_DEVICE_ID"], "timestamp": datetime.now(), 
                  "temperature": msgValue["TEMPERATURE"], "humidity": msgValue["HUMIDITY"], "rd": msgValue["T_RD"]}
            print("json=",  j)
            
            # 將資料存入 mongodb
            # 存入單筆
            #result = collection.insert_one(j)
            # 存入多筆
            #result = collection.insert_many()
            print(result)
            res = es.index(index="temp_humidity1", doc_type='tweet', id=datetime.now(), body=j)
            print(res['result'])

    except:
        # 錯誤處理
        e_type, e_value, e_traceback = sys.exc_info()
        print("type ==> %s" % (e_type))
        print("value ==> %s" % (e_value))
        print("traceback ==> file name: %s" % (e_traceback.tb_frame.f_code.co_filename))
        print("traceback ==> line no: %s" % (e_traceback.tb_lineno))
        print("traceback ==> function name: %s" % (e_traceback.tb_frame.f_code.co_name))
    finally:
        consumer.close()
# Out:
# Now listening for incoming messages ...
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=0 : (key=b'0.14562536344048926', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:02:05', 'TEMPERATURE': 27.67, 'HUMIDITY': 26, 'T_RD': '0.14562536344048926'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 313819), 'temperature': 27.67, 'humidity': 26, 'rd': '0.14562536344048926'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=1 : (key=b'0.9677200796285044', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:02:07', 'TEMPERATURE': 25.2, 'HUMIDITY': 90, 'T_RD': '0.9677200796285044'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 319125), 'temperature': 25.2, 'humidity': 90, 'rd': '0.9677200796285044'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=2 : (key=b'0.016204755833040596', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:02:11', 'TEMPERATURE': 25.66, 'HUMIDITY': 86, 'T_RD': '0.016204755833040596'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 322702), 'temperature': 25.66, 'humidity': 86, 'rd': '0.016204755833040596'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=3 : (key=b'0.20692436147371285', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:02:14', 'TEMPERATURE': 29.82, 'HUMIDITY': 25, 'T_RD': '0.20692436147371285'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 326911), 'temperature': 29.82, 'humidity': 25, 'rd': '0.20692436147371285'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=4 : (key=b'0.7857743710891081', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:02:20', 'TEMPERATURE': 28.37, 'HUMIDITY': 26, 'T_RD': '0.7857743710891081'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 330268), 'temperature': 28.37, 'humidity': 26, 'rd': '0.7857743710891081'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=5 : (key=b'0.6723213369255329', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:02:27', 'TEMPERATURE': 19.26, 'HUMIDITY': 80, 'T_RD': '0.6723213369255329'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 335589), 'temperature': 19.26, 'humidity': 80, 'rd': '0.6723213369255329'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=6 : (key=b'0.7489120506386698', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:02:43', 'TEMPERATURE': 20.2, 'HUMIDITY': 34, 'T_RD': '0.7489120506386698'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 339002), 'temperature': 20.2, 'humidity': 34, 'rd': '0.7489120506386698'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=7 : (key=b'0.5868458318774032', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:02:50', 'TEMPERATURE': 28.42, 'HUMIDITY': 43, 'T_RD': '0.5868458318774032'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 344624), 'temperature': 28.42, 'humidity': 43, 'rd': '0.5868458318774032'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=8 : (key=b'0.5173610554208893', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:03:08', 'TEMPERATURE': 19.08, 'HUMIDITY': 11, 'T_RD': '0.5173610554208893'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 351202), 'temperature': 19.08, 'humidity': 11, 'rd': '0.5173610554208893'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=9 : (key=b'0.02205934541917376', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:03:10', 'TEMPERATURE': 19.44, 'HUMIDITY': 23, 'T_RD': '0.02205934541917376'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 355720), 'temperature': 19.44, 'humidity': 23, 'rd': '0.02205934541917376'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=10 : (key=b'0.3658715197102942', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:03:17', 'TEMPERATURE': 24.26, 'HUMIDITY': 18, 'T_RD': '0.3658715197102942'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 359990), 'temperature': 24.26, 'humidity': 18, 'rd': '0.3658715197102942'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=11 : (key=b'0.8262219945300114', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:03:19', 'TEMPERATURE': 18.27, 'HUMIDITY': 23, 'T_RD': '0.8262219945300114'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 368513), 'temperature': 18.27, 'humidity': 23, 'rd': '0.8262219945300114'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=12 : (key=b'0.2267457060018091', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:03:30', 'TEMPERATURE': 19.4, 'HUMIDITY': 97, 'T_RD': '0.2267457060018091'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 372756), 'temperature': 19.4, 'humidity': 97, 'rd': '0.2267457060018091'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=13 : (key=b'0.17083484947046368', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:03:32', 'TEMPERATURE': 25.91, 'HUMIDITY': 7, 'T_RD': '0.17083484947046368'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 379085), 'temperature': 25.91, 'humidity': 7, 'rd': '0.17083484947046368'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=14 : (key=b'0.8659687330486371', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:03:37', 'TEMPERATURE': 20.17, 'HUMIDITY': 81, 'T_RD': '0.8659687330486371'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 382969), 'temperature': 20.17, 'humidity': 81, 'rd': '0.8659687330486371'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=15 : (key=b'0.6008070491407498', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:03:46', 'TEMPERATURE': 20.8, 'HUMIDITY': 85, 'T_RD': '0.6008070491407498'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 386554), 'temperature': 20.8, 'humidity': 85, 'rd': '0.6008070491407498'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=16 : (key=b'0.09422131413911072', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:03:48', 'TEMPERATURE': 24.55, 'HUMIDITY': 5, 'T_RD': '0.09422131413911072'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 389631), 'temperature': 24.55, 'humidity': 5, 'rd': '0.09422131413911072'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=17 : (key=b'0.681647549074256', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:03:57', 'TEMPERATURE': 18.18, 'HUMIDITY': 34, 'T_RD': '0.681647549074256'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 394382), 'temperature': 18.18, 'humidity': 34, 'rd': '0.681647549074256'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=18 : (key=b'0.6835331963009627', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:10:06', 'TEMPERATURE': 18.23, 'HUMIDITY': 57, 'T_RD': '0.6835331963009627'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 397631), 'temperature': 18.23, 'humidity': 57, 'rd': '0.6835331963009627'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=19 : (key=b'0.1256987417094485', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:10:21', 'TEMPERATURE': 29.12, 'HUMIDITY': 40, 'T_RD': '0.1256987417094485'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 400705), 'temperature': 29.12, 'humidity': 40, 'rd': '0.1256987417094485'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=20 : (key=b'0.8568449695405325', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:10:24', 'TEMPERATURE': 24.68, 'HUMIDITY': 22, 'T_RD': '0.8568449695405325'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 403662), 'temperature': 24.68, 'humidity': 22, 'rd': '0.8568449695405325'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=21 : (key=b'0.5922864172615688', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:10:44', 'TEMPERATURE': 27.75, 'HUMIDITY': 2, 'T_RD': '0.5922864172615688'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 407455), 'temperature': 27.75, 'humidity': 2, 'rd': '0.5922864172615688'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=22 : (key=b'0.13562408173111917', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:10:55', 'TEMPERATURE': 24.53, 'HUMIDITY': 13, 'T_RD': '0.13562408173111917'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 410874), 'temperature': 24.53, 'humidity': 13, 'rd': '0.13562408173111917'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=23 : (key=b'0.22604021357593007', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:10:58', 'TEMPERATURE': 27.35, 'HUMIDITY': 90, 'T_RD': '0.22604021357593007'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 413954), 'temperature': 27.35, 'humidity': 90, 'rd': '0.22604021357593007'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=24 : (key=b'0.9605983904805897', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:11:20', 'TEMPERATURE': 26.73, 'HUMIDITY': 78, 'T_RD': '0.9605983904805897'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 417380), 'temperature': 26.73, 'humidity': 78, 'rd': '0.9605983904805897'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# created
# topic=TEMP_HUMIDITY_ENRICHED, partition=3, offset=25 : (key=b'0.44529320149637774', value={'T_DEVICE_ID': '001', 'T_TIMESTAMP': '2019-09-19 08:11:22', 'TEMPERATURE': 23.16, 'HUMIDITY': 68, 'T_RD': '0.44529320149637774'})
# json= {'device_id': '001', 'timestamp': datetime.datetime(2019, 9, 19, 8, 47, 15, 421373), 'temperature': 23.16, 'humidity': 68, 'rd': '0.44529320149637774'}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# type ==> <class 'KeyboardInterrupt'>
# value ==>
# traceback ==> file name: <ipython-input-19-5e6040d54606>
# traceback ==> line no: 62
# traceback ==> function name: <module>

# %%
## step test
from kafka import KafkaConsumer
import sys, json, pymysql, pymongo


if __name__ == "__main__":

    # 與 MongoDB連線
    client = pymongo.MongoClient(host="mongodb", port=27017)
    # 指定為 test 資料庫
    db = client.test
    # 指定 temp_humidity 集合, MongoDB的每個資料庫又包含許多集合(collection), 類似於關聯性資料庫中的表
    collection = db.step

    # 設定要連線到Kafka集群的相關設定, 產生一個Kafka的Consumer的實例
    consumer = KafkaConsumer(
        # 指定Kafka集群伺服器
        bootstrap_servers=["kafka:9092"],
        # ConsumerGroup的名稱, 可以不指定
        #group_id="cg_001",
        # 指定msgKey的反序列化器, 若Key為None, 無法反序列化
        # key_deserializer=bytes.decode,
        # 指定msgValue的反序列化器
        #value_deserializer=bytes.decode,
        value_deserializer=lambda m: json.loads(m.decode('ascii')),
        # 是否從這個ConsumerGroup尚未讀取的partition / offset開始讀
        auto_offset_reset="earliest",
    )
   
    # 讓Consumer向Kafka集群訂閱指定的topic
    consumer.subscribe(topics="step")
    
    #es = Elasticsearch('http://elasticsearch:9200')
    
    
    # 持續的拉取Kafka有進來的訊息
    try:
        print("Now listening for incoming messages ...")
        # 持續監控是否有新的record進來
        for record in consumer:
            topic = record.topic
            partition = record.partition
            offset = record.offset
            timestamp = record.timestamp
            # 取出msgKey與msgValue
            msgKey = record.key
            msgValue = record.value
            # 秀出metadata與msgKey & msgValue訊息
            print("topic=%s, partition=%s, offset=%s : (key=%s, value=%s)" % (record.topic, record.partition, 
                                                                              record.offset, record.key, record.value))
            j = {"device_id": msgValue["ID"], "timestamp": msgValue["DateTime"], 
                 "X_unit": msgValue["X_unit"], "Y_unit": msgValue["Y_unit"], "Z_unit": msgValue["Z_unit"],
                 "Xr": msgValue["Xr"], "Yr": msgValue["Yr"], "Zr": msgValue["Zr"],
                 "Xr_unit": msgValue["Xr_unit"], "Yr_unit": msgValue["Yr_unit"], "Zr_unit": msgValue["Zr_unit"]}
            print("json=",  j)
            
            # 將資料存入 mongodb
            # 存入單筆
            result = collection.insert_one(j)
            # 存入多筆
            #result = collection.insert_many()
            print(result)
            #res = es.index(index="temp_humidity1", doc_type='tweet', id=datetime.now(), body=j)
            #print(res['result'])

    except:
        # 錯誤處理
        e_type, e_value, e_traceback = sys.exc_info()
        print("type ==> %s" % (e_type))
        print("value ==> %s" % (e_value))
        print("traceback ==> file name: %s" % (e_traceback.tb_frame.f_code.co_filename))
        print("traceback ==> line no: %s" % (e_traceback.tb_lineno))
        print("traceback ==> function name: %s" % (e_traceback.tb_frame.f_code.co_name))
    finally:
        consumer.close()
# Out:
# Now listening for incoming messages ...
# topic=step, partition=0, offset=0 : (key=None, value={'Xr_unit': -0.09130859375, 'X_unit': -2, 'Zr_unit': 0.88671875, 'DateTime': '2019-09-19 16:55:39', 'Y_unit': -1, 'Y': -41, 'X': -198, 'Z': 109, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.345703125, 'Xr': -1496, 'Yr': 5664, 'Zr': 14528})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:39', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1496, 'Yr': 5664, 'Zr': 14528, 'Xr_unit': -0.09130859375, 'Yr_unit': 0.345703125, 'Zr_unit': 0.88671875}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=1 : (key=None, value={'Xr_unit': -0.089111328125, 'X_unit': -2, 'Zr_unit': 0.885009765625, 'DateTime': '2019-09-19 16:55:41', 'Y_unit': -1, 'Y': -44, 'X': -151, 'Z': 134, 'ID': 'ausitn', 'Z_unit': 1, 'Yr_unit': 0.349609375, 'Xr': -1460, 'Yr': 5728, 'Zr': 14500})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:41', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 1, 'Xr': -1460, 'Yr': 5728, 'Zr': 14500, 'Xr_unit': -0.089111328125, 'Yr_unit': 0.349609375, 'Zr_unit': 0.885009765625}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=2 : (key=None, value={'Xr_unit': -0.097412109375, 'X_unit': -2, 'Zr_unit': 0.884033203125, 'DateTime': '2019-09-19 16:55:41', 'Y_unit': -1, 'Y': -17, 'X': -192, 'Z': 135, 'ID': 'ausitn', 'Z_unit': 1, 'Yr_unit': 0.350830078125, 'Xr': -1596, 'Yr': 5748, 'Zr': 14484})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:41', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 1, 'Xr': -1596, 'Yr': 5748, 'Zr': 14484, 'Xr_unit': -0.097412109375, 'Yr_unit': 0.350830078125, 'Zr_unit': 0.884033203125}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=3 : (key=None, value={'Xr_unit': -0.107666015625, 'X_unit': -2, 'Zr_unit': 0.87255859375, 'DateTime': '2019-09-19 16:55:41', 'Y_unit': -1, 'Y': -48, 'X': -192, 'Z': 115, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.3408203125, 'Xr': -1764, 'Yr': 5584, 'Zr': 14296})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:41', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1764, 'Yr': 5584, 'Zr': 14296, 'Xr_unit': -0.107666015625, 'Yr_unit': 0.3408203125, 'Zr_unit': 0.87255859375}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=4 : (key=None, value={'Xr_unit': -0.094970703125, 'X_unit': -2, 'Zr_unit': 0.8798828125, 'DateTime': '2019-09-19 16:55:41', 'Y_unit': -1, 'Y': -11, 'X': -179, 'Z': 111, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.349365234375, 'Xr': -1556, 'Yr': 5724, 'Zr': 14416})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:41', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1556, 'Yr': 5724, 'Zr': 14416, 'Xr_unit': -0.094970703125, 'Yr_unit': 0.349365234375, 'Zr_unit': 0.8798828125}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=5 : (key=None, value={'Xr_unit': -0.100830078125, 'X_unit': -2, 'Zr_unit': 0.875244140625, 'DateTime': '2019-09-19 16:55:41', 'Y_unit': -1, 'Y': -52, 'X': -186, 'Z': 87, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.33349609375, 'Xr': -1652, 'Yr': 5464, 'Zr': 14340})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:41', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1652, 'Yr': 5464, 'Zr': 14340, 'Xr_unit': -0.100830078125, 'Yr_unit': 0.33349609375, 'Zr_unit': 0.875244140625}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=6 : (key=None, value={'Xr_unit': -0.081298828125, 'X_unit': -2, 'Zr_unit': 0.883056640625, 'DateTime': '2019-09-19 16:55:41', 'Y_unit': -1, 'Y': -45, 'X': -172, 'Z': 101, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.35205078125, 'Xr': -1332, 'Yr': 5768, 'Zr': 14468})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:41', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1332, 'Yr': 5768, 'Zr': 14468, 'Xr_unit': -0.081298828125, 'Yr_unit': 0.35205078125, 'Zr_unit': 0.883056640625}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=7 : (key=None, value={'Xr_unit': -0.0966796875, 'X_unit': -2, 'Zr_unit': 0.875244140625, 'DateTime': '2019-09-19 16:55:41', 'Y_unit': -1, 'Y': -51, 'X': -181, 'Z': 129, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.34765625, 'Xr': -1584, 'Yr': 5696, 'Zr': 14340})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:41', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1584, 'Yr': 5696, 'Zr': 14340, 'Xr_unit': -0.0966796875, 'Yr_unit': 0.34765625, 'Zr_unit': 0.875244140625}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=8 : (key=None, value={'Xr_unit': -0.093017578125, 'X_unit': -2, 'Zr_unit': 0.88720703125, 'DateTime': '2019-09-19 16:55:41', 'Y_unit': -1, 'Y': -49, 'X': -152, 'Z': 76, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.35009765625, 'Xr': -1524, 'Yr': 5736, 'Zr': 14536})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:41', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1524, 'Yr': 5736, 'Zr': 14536, 'Xr_unit': -0.093017578125, 'Yr_unit': 0.35009765625, 'Zr_unit': 0.88720703125}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=9 : (key=None, value={'Xr_unit': -0.1083984375, 'X_unit': -2, 'Zr_unit': 0.87646484375, 'DateTime': '2019-09-19 16:55:42', 'Y_unit': 0, 'Y': 18, 'X': -169, 'Z': 102, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.345947265625, 'Xr': -1776, 'Yr': 5668, 'Zr': 14360})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:42', 'X_unit': -2, 'Y_unit': 0, 'Z_unit': 0, 'Xr': -1776, 'Yr': 5668, 'Zr': 14360, 'Xr_unit': -0.1083984375, 'Yr_unit': 0.345947265625, 'Zr_unit': 0.87646484375}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=10 : (key=None, value={'Xr_unit': -0.09423828125, 'X_unit': -1, 'Zr_unit': 0.87451171875, 'DateTime': '2019-09-19 16:55:43', 'Y_unit': -1, 'Y': -42, 'X': -80, 'Z': 168, 'ID': 'ausitn', 'Z_unit': 1, 'Yr_unit': 0.35205078125, 'Xr': -1544, 'Yr': 5768, 'Zr': 14328})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:43', 'X_unit': -1, 'Y_unit': -1, 'Z_unit': 1, 'Xr': -1544, 'Yr': 5768, 'Zr': 14328, 'Xr_unit': -0.09423828125, 'Yr_unit': 0.35205078125, 'Zr_unit': 0.87451171875}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=11 : (key=None, value={'Xr_unit': -0.0927734375, 'X_unit': -2, 'Zr_unit': 0.86865234375, 'DateTime': '2019-09-19 16:55:43', 'Y_unit': -1, 'Y': -52, 'X': -235, 'Z': 91, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.349609375, 'Xr': -1520, 'Yr': 5728, 'Zr': 14232})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:43', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1520, 'Yr': 5728, 'Zr': 14232, 'Xr_unit': -0.0927734375, 'Yr_unit': 0.349609375, 'Zr_unit': 0.86865234375}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=12 : (key=None, value={'Xr_unit': -0.089599609375, 'X_unit': -1, 'Zr_unit': 0.87939453125, 'DateTime': '2019-09-19 16:55:43', 'Y_unit': -1, 'Y': -51, 'X': -93, 'Z': 139, 'ID': 'ausitn', 'Z_unit': 1, 'Yr_unit': 0.35107421875, 'Xr': -1468, 'Yr': 5752, 'Zr': 14408})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:43', 'X_unit': -1, 'Y_unit': -1, 'Z_unit': 1, 'Xr': -1468, 'Yr': 5752, 'Zr': 14408, 'Xr_unit': -0.089599609375, 'Yr_unit': 0.35107421875, 'Zr_unit': 0.87939453125}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=13 : (key=None, value={'Xr_unit': -0.09326171875, 'X_unit': -1, 'Zr_unit': 0.877685546875, 'DateTime': '2019-09-19 16:55:43', 'Y_unit': -1, 'Y': -53, 'X': -106, 'Z': 124, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.345947265625, 'Xr': -1528, 'Yr': 5668, 'Zr': 14380})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:43', 'X_unit': -1, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1528, 'Yr': 5668, 'Zr': 14380, 'Xr_unit': -0.09326171875, 'Yr_unit': 0.345947265625, 'Zr_unit': 0.877685546875}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=14 : (key=None, value={'Xr_unit': -0.091552734375, 'X_unit': -1, 'Zr_unit': 0.868408203125, 'DateTime': '2019-09-19 16:55:44', 'Y_unit': -1, 'Y': -94, 'X': -120, 'Z': 123, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.3544921875, 'Xr': -1500, 'Yr': 5808, 'Zr': 14228})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:44', 'X_unit': -1, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1500, 'Yr': 5808, 'Zr': 14228, 'Xr_unit': -0.091552734375, 'Yr_unit': 0.3544921875, 'Zr_unit': 0.868408203125}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=15 : (key=None, value={'Xr_unit': -0.082763671875, 'X_unit': -2, 'Zr_unit': 0.87158203125, 'DateTime': '2019-09-19 16:55:44', 'Y_unit': -1, 'Y': -51, 'X': -233, 'Z': 95, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.347412109375, 'Xr': -1356, 'Yr': 5692, 'Zr': 14280})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:44', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1356, 'Yr': 5692, 'Zr': 14280, 'Xr_unit': -0.082763671875, 'Yr_unit': 0.347412109375, 'Zr_unit': 0.87158203125}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=16 : (key=None, value={'Xr_unit': -0.08154296875, 'X_unit': -1, 'Zr_unit': 0.889404296875, 'DateTime': '2019-09-19 16:55:44', 'Y_unit': -1, 'Y': -75, 'X': -125, 'Z': 108, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.354248046875, 'Xr': -1336, 'Yr': 5804, 'Zr': 14572})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:44', 'X_unit': -1, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1336, 'Yr': 5804, 'Zr': 14572, 'Xr_unit': -0.08154296875, 'Yr_unit': 0.354248046875, 'Zr_unit': 0.889404296875}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=17 : (key=None, value={'Xr_unit': -0.103515625, 'X_unit': -2, 'Zr_unit': 0.8818359375, 'DateTime': '2019-09-19 16:55:44', 'Y_unit': -1, 'Y': -60, 'X': -187, 'Z': 105, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.354248046875, 'Xr': -1696, 'Yr': 5804, 'Zr': 14448})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:44', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1696, 'Yr': 5804, 'Zr': 14448, 'Xr_unit': -0.103515625, 'Yr_unit': 0.354248046875, 'Zr_unit': 0.8818359375}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=18 : (key=None, value={'Xr_unit': -0.085693359375, 'X_unit': -2, 'Zr_unit': 0.87255859375, 'DateTime': '2019-09-19 16:55:44', 'Y_unit': -1, 'Y': -21, 'X': -165, 'Z': 122, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.351318359375, 'Xr': -1404, 'Yr': 5756, 'Zr': 14296})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:44', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1404, 'Yr': 5756, 'Zr': 14296, 'Xr_unit': -0.085693359375, 'Yr_unit': 0.351318359375, 'Zr_unit': 0.87255859375}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=19 : (key=None, value={'Xr_unit': -0.096923828125, 'X_unit': -2, 'Zr_unit': 0.885498046875, 'DateTime': '2019-09-19 16:55:44', 'Y_unit': -1, 'Y': -51, 'X': -140, 'Z': 125, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.3486328125, 'Xr': -1588, 'Yr': 5712, 'Zr': 14508})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:44', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1588, 'Yr': 5712, 'Zr': 14508, 'Xr_unit': -0.096923828125, 'Yr_unit': 0.3486328125, 'Zr_unit': 0.885498046875}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=20 : (key=None, value={'Xr_unit': -0.091796875, 'X_unit': -2, 'Zr_unit': 0.900390625, 'DateTime': '2019-09-19 16:55:45', 'Y_unit': -1, 'Y': -53, 'X': -146, 'Z': 108, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.351806640625, 'Xr': -1504, 'Yr': 5764, 'Zr': 14752})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:45', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1504, 'Yr': 5764, 'Zr': 14752, 'Xr_unit': -0.091796875, 'Yr_unit': 0.351806640625, 'Zr_unit': 0.900390625}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=21 : (key=None, value={'Xr_unit': -0.10888671875, 'X_unit': -1, 'Zr_unit': 0.87548828125, 'DateTime': '2019-09-19 16:55:45', 'Y_unit': -1, 'Y': -52, 'X': -122, 'Z': 124, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.352294921875, 'Xr': -1784, 'Yr': 5772, 'Zr': 14344})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:45', 'X_unit': -1, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1784, 'Yr': 5772, 'Zr': 14344, 'Xr_unit': -0.10888671875, 'Yr_unit': 0.352294921875, 'Zr_unit': 0.87548828125}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=22 : (key=None, value={'Xr_unit': -0.091796875, 'X_unit': -2, 'Zr_unit': 0.878662109375, 'DateTime': '2019-09-19 16:55:45', 'Y_unit': -1, 'Y': -82, 'X': -211, 'Z': 79, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.3515625, 'Xr': -1504, 'Yr': 5760, 'Zr': 14396})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:45', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1504, 'Yr': 5760, 'Zr': 14396, 'Xr_unit': -0.091796875, 'Yr_unit': 0.3515625, 'Zr_unit': 0.878662109375}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=23 : (key=None, value={'Xr_unit': -0.096435546875, 'X_unit': -2, 'Zr_unit': 0.87548828125, 'DateTime': '2019-09-19 16:55:45', 'Y_unit': -1, 'Y': -46, 'X': -136, 'Z': 124, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.355224609375, 'Xr': -1580, 'Yr': 5820, 'Zr': 14344})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:45', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1580, 'Yr': 5820, 'Zr': 14344, 'Xr_unit': -0.096435546875, 'Yr_unit': 0.355224609375, 'Zr_unit': 0.87548828125}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=24 : (key=None, value={'Xr_unit': -0.094482421875, 'X_unit': -2, 'Zr_unit': 0.8740234375, 'DateTime': '2019-09-19 16:55:45', 'Y_unit': -1, 'Y': -35, 'X': -147, 'Z': 139, 'ID': 'ausitn', 'Z_unit': 1, 'Yr_unit': 0.34765625, 'Xr': -1548, 'Yr': 5696, 'Zr': 14320})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:45', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 1, 'Xr': -1548, 'Yr': 5696, 'Zr': 14320, 'Xr_unit': -0.094482421875, 'Yr_unit': 0.34765625, 'Zr_unit': 0.8740234375}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=25 : (key=None, value={'Xr_unit': -0.078369140625, 'X_unit': -1, 'Zr_unit': 0.884033203125, 'DateTime': '2019-09-19 16:55:45', 'Y_unit': -1, 'Y': -53, 'X': -12, 'Z': 98, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.345703125, 'Xr': -1284, 'Yr': 5664, 'Zr': 14484})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:45', 'X_unit': -1, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1284, 'Yr': 5664, 'Zr': 14484, 'Xr_unit': -0.078369140625, 'Yr_unit': 0.345703125, 'Zr_unit': 0.884033203125}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=26 : (key=None, value={'Xr_unit': -0.0927734375, 'X_unit': -2, 'Zr_unit': 0.880859375, 'DateTime': '2019-09-19 16:55:45', 'Y_unit': -1, 'Y': -32, 'X': -147, 'Z': 96, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.350341796875, 'Xr': -1520, 'Yr': 5740, 'Zr': 14432})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:45', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1520, 'Yr': 5740, 'Zr': 14432, 'Xr_unit': -0.0927734375, 'Yr_unit': 0.350341796875, 'Zr_unit': 0.880859375}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=27 : (key=None, value={'Xr_unit': -0.091796875, 'X_unit': -2, 'Zr_unit': 0.889404296875, 'DateTime': '2019-09-19 16:55:45', 'Y_unit': -1, 'Y': -18, 'X': -146, 'Z': 134, 'ID': 'ausitn', 'Z_unit': 1, 'Yr_unit': 0.351806640625, 'Xr': -1504, 'Yr': 5764, 'Zr': 14572})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:45', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 1, 'Xr': -1504, 'Yr': 5764, 'Zr': 14572, 'Xr_unit': -0.091796875, 'Yr_unit': 0.351806640625, 'Zr_unit': 0.889404296875}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=28 : (key=None, value={'Xr_unit': -0.10791015625, 'X_unit': -2, 'Zr_unit': 0.89111328125, 'DateTime': '2019-09-19 16:55:45', 'Y_unit': -1, 'Y': -50, 'X': -184, 'Z': 73, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.350341796875, 'Xr': -1768, 'Yr': 5740, 'Zr': 14600})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:45', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1768, 'Yr': 5740, 'Zr': 14600, 'Xr_unit': -0.10791015625, 'Yr_unit': 0.350341796875, 'Zr_unit': 0.89111328125}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=29 : (key=None, value={'Xr_unit': -0.097412109375, 'X_unit': -3, 'Zr_unit': 0.876220703125, 'DateTime': '2019-09-19 16:55:45', 'Y_unit': -1, 'Y': -39, 'X': -275, 'Z': 75, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.344970703125, 'Xr': -1596, 'Yr': 5652, 'Zr': 14356})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:45', 'X_unit': -3, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1596, 'Yr': 5652, 'Zr': 14356, 'Xr_unit': -0.097412109375, 'Yr_unit': 0.344970703125, 'Zr_unit': 0.876220703125}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=30 : (key=None, value={'Xr_unit': -0.098388671875, 'X_unit': -2, 'Zr_unit': 0.864501953125, 'DateTime': '2019-09-19 16:55:46', 'Y_unit': -1, 'Y': -65, 'X': -185, 'Z': 75, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.349609375, 'Xr': -1612, 'Yr': 5728, 'Zr': 14164})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:46', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1612, 'Yr': 5728, 'Zr': 14164, 'Xr_unit': -0.098388671875, 'Yr_unit': 0.349609375, 'Zr_unit': 0.864501953125}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=31 : (key=None, value={'Xr_unit': -0.106689453125, 'X_unit': -1, 'Zr_unit': 0.876953125, 'DateTime': '2019-09-19 16:55:46', 'Y_unit': -1, 'Y': -40, 'X': -116, 'Z': 143, 'ID': 'ausitn', 'Z_unit': 1, 'Yr_unit': 0.35205078125, 'Xr': -1748, 'Yr': 5768, 'Zr': 14368})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:46', 'X_unit': -1, 'Y_unit': -1, 'Z_unit': 1, 'Xr': -1748, 'Yr': 5768, 'Zr': 14368, 'Xr_unit': -0.106689453125, 'Yr_unit': 0.35205078125, 'Zr_unit': 0.876953125}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=32 : (key=None, value={'Xr_unit': -0.083251953125, 'X_unit': -3, 'Zr_unit': 0.88427734375, 'DateTime': '2019-09-19 16:55:46', 'Y_unit': -1, 'Y': -67, 'X': -291, 'Z': 80, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.345703125, 'Xr': -1364, 'Yr': 5664, 'Zr': 14488})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:46', 'X_unit': -3, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1364, 'Yr': 5664, 'Zr': 14488, 'Xr_unit': -0.083251953125, 'Yr_unit': 0.345703125, 'Zr_unit': 0.88427734375}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=33 : (key=None, value={'Xr_unit': -0.095458984375, 'X_unit': -3, 'Zr_unit': 0.87744140625, 'DateTime': '2019-09-19 16:55:46', 'Y_unit': -1, 'Y': -30, 'X': -289, 'Z': 71, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.35107421875, 'Xr': -1564, 'Yr': 5752, 'Zr': 14376})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:46', 'X_unit': -3, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1564, 'Yr': 5752, 'Zr': 14376, 'Xr_unit': -0.095458984375, 'Yr_unit': 0.35107421875, 'Zr_unit': 0.87744140625}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=34 : (key=None, value={'Xr_unit': -0.09619140625, 'X_unit': -3, 'Zr_unit': 0.904296875, 'DateTime': '2019-09-19 16:55:46', 'Y_unit': -1, 'Y': -44, 'X': -288, 'Z': 84, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.34912109375, 'Xr': -1576, 'Yr': 5720, 'Zr': 14816})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:46', 'X_unit': -3, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1576, 'Yr': 5720, 'Zr': 14816, 'Xr_unit': -0.09619140625, 'Yr_unit': 0.34912109375, 'Zr_unit': 0.904296875}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=35 : (key=None, value={'Xr_unit': -0.090576171875, 'X_unit': -3, 'Zr_unit': 0.87255859375, 'DateTime': '2019-09-19 16:55:46', 'Y_unit': -1, 'Y': -69, 'X': -301, 'Z': 70, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.344482421875, 'Xr': -1484, 'Yr': 5644, 'Zr': 14296})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:46', 'X_unit': -3, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1484, 'Yr': 5644, 'Zr': 14296, 'Xr_unit': -0.090576171875, 'Yr_unit': 0.344482421875, 'Zr_unit': 0.87255859375}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=36 : (key=None, value={'Xr_unit': -0.086181640625, 'X_unit': -3, 'Zr_unit': 0.8798828125, 'DateTime': '2019-09-19 16:55:46', 'Y_unit': -1, 'Y': -28, 'X': -275, 'Z': 55, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.3505859375, 'Xr': -1412, 'Yr': 5744, 'Zr': 14416})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:46', 'X_unit': -3, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1412, 'Yr': 5744, 'Zr': 14416, 'Xr_unit': -0.086181640625, 'Yr_unit': 0.3505859375, 'Zr_unit': 0.8798828125}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=37 : (key=None, value={'Xr_unit': -0.10888671875, 'X_unit': -2, 'Zr_unit': 0.887939453125, 'DateTime': '2019-09-19 16:55:46', 'Y_unit': -1, 'Y': -46, 'X': -249, 'Z': 92, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.3583984375, 'Xr': -1784, 'Yr': 5872, 'Zr': 14548})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:46', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1784, 'Yr': 5872, 'Zr': 14548, 'Xr_unit': -0.10888671875, 'Yr_unit': 0.3583984375, 'Zr_unit': 0.887939453125}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=38 : (key=None, value={'Xr_unit': -0.098876953125, 'X_unit': -2, 'Zr_unit': 0.885986328125, 'DateTime': '2019-09-19 16:55:46', 'Y_unit': -1, 'Y': -78, 'X': -149, 'Z': 96, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.348388671875, 'Xr': -1620, 'Yr': 5708, 'Zr': 14516})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:46', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1620, 'Yr': 5708, 'Zr': 14516, 'Xr_unit': -0.098876953125, 'Yr_unit': 0.348388671875, 'Zr_unit': 0.885986328125}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=39 : (key=None, value={'Xr_unit': -0.09130859375, 'X_unit': -2, 'Zr_unit': 0.88427734375, 'DateTime': '2019-09-19 16:55:46', 'Y_unit': -1, 'Y': -36, 'X': -197, 'Z': 106, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.328125, 'Xr': -1496, 'Yr': 5376, 'Zr': 14488})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:46', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1496, 'Yr': 5376, 'Zr': 14488, 'Xr_unit': -0.09130859375, 'Yr_unit': 0.328125, 'Zr_unit': 0.88427734375}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=40 : (key=None, value={'Xr_unit': -0.09326171875, 'X_unit': -2, 'Zr_unit': 0.884521484375, 'DateTime': '2019-09-19 16:55:47', 'Y_unit': 1, 'Y': 238, 'X': -162, 'Z': 127, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.35009765625, 'Xr': -1528, 'Yr': 5736, 'Zr': 14492})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:47', 'X_unit': -2, 'Y_unit': 1, 'Z_unit': 0, 'Xr': -1528, 'Yr': 5736, 'Zr': 14492, 'Xr_unit': -0.09326171875, 'Yr_unit': 0.35009765625, 'Zr_unit': 0.884521484375}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=41 : (key=None, value={'Xr_unit': -0.0869140625, 'X_unit': -2, 'Zr_unit': 0.886474609375, 'DateTime': '2019-09-19 16:55:47', 'Y_unit': -1, 'Y': -59, 'X': -256, 'Z': 109, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.334228515625, 'Xr': -1424, 'Yr': 5476, 'Zr': 14524})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:47', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1424, 'Yr': 5476, 'Zr': 14524, 'Xr_unit': -0.0869140625, 'Yr_unit': 0.334228515625, 'Zr_unit': 0.886474609375}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=42 : (key=None, value={'Xr_unit': -0.087646484375, 'X_unit': -2, 'Zr_unit': 0.890380859375, 'DateTime': '2019-09-19 16:55:47', 'Y_unit': -1, 'Y': -41, 'X': -213, 'Z': 118, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.34716796875, 'Xr': -1436, 'Yr': 5688, 'Zr': 14588})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:47', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1436, 'Yr': 5688, 'Zr': 14588, 'Xr_unit': -0.087646484375, 'Yr_unit': 0.34716796875, 'Zr_unit': 0.890380859375}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=43 : (key=None, value={'Xr_unit': -0.08642578125, 'X_unit': -2, 'Zr_unit': 0.87744140625, 'DateTime': '2019-09-19 16:55:47', 'Y_unit': -1, 'Y': -38, 'X': -159, 'Z': 136, 'ID': 'ausitn', 'Z_unit': 1, 'Yr_unit': 0.354736328125, 'Xr': -1416, 'Yr': 5812, 'Zr': 14376})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:47', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 1, 'Xr': -1416, 'Yr': 5812, 'Zr': 14376, 'Xr_unit': -0.08642578125, 'Yr_unit': 0.354736328125, 'Zr_unit': 0.87744140625}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=44 : (key=None, value={'Xr_unit': -0.0947265625, 'X_unit': -1, 'Zr_unit': 0.871337890625, 'DateTime': '2019-09-19 16:55:47', 'Y_unit': -1, 'Y': -16, 'X': -50, 'Z': 128, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.35546875, 'Xr': -1552, 'Yr': 5824, 'Zr': 14276})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:47', 'X_unit': -1, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1552, 'Yr': 5824, 'Zr': 14276, 'Xr_unit': -0.0947265625, 'Yr_unit': 0.35546875, 'Zr_unit': 0.871337890625}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=45 : (key=None, value={'Xr_unit': -0.107421875, 'X_unit': -1, 'Zr_unit': 0.881103515625, 'DateTime': '2019-09-19 16:55:47', 'Y_unit': -1, 'Y': -46, 'X': -119, 'Z': 143, 'ID': 'ausitn', 'Z_unit': 1, 'Yr_unit': 0.34765625, 'Xr': -1760, 'Yr': 5696, 'Zr': 14436})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:47', 'X_unit': -1, 'Y_unit': -1, 'Z_unit': 1, 'Xr': -1760, 'Yr': 5696, 'Zr': 14436, 'Xr_unit': -0.107421875, 'Yr_unit': 0.34765625, 'Zr_unit': 0.881103515625}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=46 : (key=None, value={'Xr_unit': -0.092529296875, 'X_unit': -1, 'Zr_unit': 0.88671875, 'DateTime': '2019-09-19 16:55:47', 'Y_unit': -1, 'Y': -41, 'X': -4, 'Z': 102, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.35302734375, 'Xr': -1516, 'Yr': 5784, 'Zr': 14528})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:47', 'X_unit': -1, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1516, 'Yr': 5784, 'Zr': 14528, 'Xr_unit': -0.092529296875, 'Yr_unit': 0.35302734375, 'Zr_unit': 0.88671875}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=47 : (key=None, value={'Xr_unit': -0.1064453125, 'X_unit': -2, 'Zr_unit': 0.878662109375, 'DateTime': '2019-09-19 16:55:47', 'Y_unit': -1, 'Y': -18, 'X': -230, 'Z': 98, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.359619140625, 'Xr': -1744, 'Yr': 5892, 'Zr': 14396})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:47', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1744, 'Yr': 5892, 'Zr': 14396, 'Xr_unit': -0.1064453125, 'Yr_unit': 0.359619140625, 'Zr_unit': 0.878662109375}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=48 : (key=None, value={'Xr_unit': -0.09765625, 'X_unit': -2, 'Zr_unit': 0.8818359375, 'DateTime': '2019-09-19 16:55:47', 'Y_unit': -1, 'Y': -67, 'X': -198, 'Z': 126, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.348388671875, 'Xr': -1600, 'Yr': 5708, 'Zr': 14448})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:47', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1600, 'Yr': 5708, 'Zr': 14448, 'Xr_unit': -0.09765625, 'Yr_unit': 0.348388671875, 'Zr_unit': 0.8818359375}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=49 : (key=None, value={'Xr_unit': -0.085693359375, 'X_unit': -2, 'Zr_unit': 0.883056640625, 'DateTime': '2019-09-19 16:55:47', 'Y_unit': -1, 'Y': -48, 'X': -192, 'Z': 114, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.353759765625, 'Xr': -1404, 'Yr': 5796, 'Zr': 14468})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:47', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1404, 'Yr': 5796, 'Zr': 14468, 'Xr_unit': -0.085693359375, 'Yr_unit': 0.353759765625, 'Zr_unit': 0.883056640625}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=50 : (key=None, value={'Xr_unit': -0.089599609375, 'X_unit': -2, 'Zr_unit': 0.890625, 'DateTime': '2019-09-19 16:55:48', 'Y_unit': -1, 'Y': -54, 'X': -196, 'Z': 81, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.349853515625, 'Xr': -1468, 'Yr': 5732, 'Zr': 14592})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:48', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1468, 'Yr': 5732, 'Zr': 14592, 'Xr_unit': -0.089599609375, 'Yr_unit': 0.349853515625, 'Zr_unit': 0.890625}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=51 : (key=None, value={'Xr_unit': -0.0810546875, 'X_unit': -2, 'Zr_unit': 0.88232421875, 'DateTime': '2019-09-19 16:55:48', 'Y_unit': -1, 'Y': -32, 'X': -162, 'Z': 120, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.351318359375, 'Xr': -1328, 'Yr': 5756, 'Zr': 14456})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:48', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1328, 'Yr': 5756, 'Zr': 14456, 'Xr_unit': -0.0810546875, 'Yr_unit': 0.351318359375, 'Zr_unit': 0.88232421875}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=52 : (key=None, value={'Xr_unit': -0.0888671875, 'X_unit': -2, 'Zr_unit': 0.889892578125, 'DateTime': '2019-09-19 16:55:48', 'Y_unit': -1, 'Y': -75, 'X': -207, 'Z': 109, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.3505859375, 'Xr': -1456, 'Yr': 5744, 'Zr': 14580})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:48', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1456, 'Yr': 5744, 'Zr': 14580, 'Xr_unit': -0.0888671875, 'Yr_unit': 0.3505859375, 'Zr_unit': 0.889892578125}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=53 : (key=None, value={'Xr_unit': -0.078369140625, 'X_unit': -2, 'Zr_unit': 0.87939453125, 'DateTime': '2019-09-19 16:55:48', 'Y_unit': -1, 'Y': -61, 'X': -225, 'Z': 68, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.341064453125, 'Xr': -1284, 'Yr': 5588, 'Zr': 14408})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:48', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1284, 'Yr': 5588, 'Zr': 14408, 'Xr_unit': -0.078369140625, 'Yr_unit': 0.341064453125, 'Zr_unit': 0.87939453125}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=54 : (key=None, value={'Xr_unit': -0.099609375, 'X_unit': -2, 'Zr_unit': 0.878662109375, 'DateTime': '2019-09-19 16:55:48', 'Y_unit': -1, 'Y': -48, 'X': -194, 'Z': 100, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.34716796875, 'Xr': -1632, 'Yr': 5688, 'Zr': 14396})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:48', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1632, 'Yr': 5688, 'Zr': 14396, 'Xr_unit': -0.099609375, 'Yr_unit': 0.34716796875, 'Zr_unit': 0.878662109375}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=55 : (key=None, value={'Xr_unit': -0.090576171875, 'X_unit': -2, 'Zr_unit': 0.885986328125, 'DateTime': '2019-09-19 16:55:48', 'Y_unit': -1, 'Y': -38, 'X': -156, 'Z': 126, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.345947265625, 'Xr': -1484, 'Yr': 5668, 'Zr': 14516})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:48', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1484, 'Yr': 5668, 'Zr': 14516, 'Xr_unit': -0.090576171875, 'Yr_unit': 0.345947265625, 'Zr_unit': 0.885986328125}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=56 : (key=None, value={'Xr_unit': -0.101806640625, 'X_unit': -2, 'Zr_unit': 0.885986328125, 'DateTime': '2019-09-19 16:55:48', 'Y_unit': -1, 'Y': -30, 'X': -135, 'Z': 111, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.358642578125, 'Xr': -1668, 'Yr': 5876, 'Zr': 14516})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:48', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1668, 'Yr': 5876, 'Zr': 14516, 'Xr_unit': -0.101806640625, 'Yr_unit': 0.358642578125, 'Zr_unit': 0.885986328125}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=57 : (key=None, value={'Xr_unit': -0.09033203125, 'X_unit': -2, 'Zr_unit': 0.877197265625, 'DateTime': '2019-09-19 16:55:48', 'Y_unit': -1, 'Y': -29, 'X': -196, 'Z': 126, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.34814453125, 'Xr': -1480, 'Yr': 5704, 'Zr': 14372})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:48', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1480, 'Yr': 5704, 'Zr': 14372, 'Xr_unit': -0.09033203125, 'Yr_unit': 0.34814453125, 'Zr_unit': 0.877197265625}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=58 : (key=None, value={'Xr_unit': -0.094482421875, 'X_unit': -2, 'Zr_unit': 0.890869140625, 'DateTime': '2019-09-19 16:55:48', 'Y_unit': -1, 'Y': -32, 'X': -215, 'Z': 102, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.349365234375, 'Xr': -1548, 'Yr': 5724, 'Zr': 14596})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:48', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1548, 'Yr': 5724, 'Zr': 14596, 'Xr_unit': -0.094482421875, 'Yr_unit': 0.349365234375, 'Zr_unit': 0.890869140625}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=59 : (key=None, value={'Xr_unit': -0.092041015625, 'X_unit': -2, 'Zr_unit': 0.882568359375, 'DateTime': '2019-09-19 16:55:49', 'Y_unit': -1, 'Y': -60, 'X': -215, 'Z': 77, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.354248046875, 'Xr': -1508, 'Yr': 5804, 'Zr': 14460})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:49', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1508, 'Yr': 5804, 'Zr': 14460, 'Xr_unit': -0.092041015625, 'Yr_unit': 0.354248046875, 'Zr_unit': 0.882568359375}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=60 : (key=None, value={'Xr_unit': -0.089111328125, 'X_unit': -1, 'Zr_unit': 0.880615234375, 'DateTime': '2019-09-19 16:55:49', 'Y_unit': -1, 'Y': -8, 'X': -32, 'Z': 142, 'ID': 'ausitn', 'Z_unit': 1, 'Yr_unit': 0.352294921875, 'Xr': -1460, 'Yr': 5772, 'Zr': 14428})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:49', 'X_unit': -1, 'Y_unit': -1, 'Z_unit': 1, 'Xr': -1460, 'Yr': 5772, 'Zr': 14428, 'Xr_unit': -0.089111328125, 'Yr_unit': 0.352294921875, 'Zr_unit': 0.880615234375}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=61 : (key=None, value={'Xr_unit': -0.097412109375, 'X_unit': -1, 'Zr_unit': 0.8876953125, 'DateTime': '2019-09-19 16:55:49', 'Y_unit': -1, 'Y': -46, 'X': -37, 'Z': 185, 'ID': 'ausitn', 'Z_unit': 1, 'Yr_unit': 0.356201171875, 'Xr': -1596, 'Yr': 5836, 'Zr': 14544})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:49', 'X_unit': -1, 'Y_unit': -1, 'Z_unit': 1, 'Xr': -1596, 'Yr': 5836, 'Zr': 14544, 'Xr_unit': -0.097412109375, 'Yr_unit': 0.356201171875, 'Zr_unit': 0.8876953125}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=62 : (key=None, value={'Xr_unit': -0.09130859375, 'X_unit': -1, 'Zr_unit': 0.8876953125, 'DateTime': '2019-09-19 16:55:49', 'Y_unit': -1, 'Y': -18, 'X': -47, 'Z': 113, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.33056640625, 'Xr': -1496, 'Yr': 5416, 'Zr': 14544})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:49', 'X_unit': -1, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1496, 'Yr': 5416, 'Zr': 14544, 'Xr_unit': -0.09130859375, 'Yr_unit': 0.33056640625, 'Zr_unit': 0.8876953125}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=63 : (key=None, value={'Xr_unit': -0.093505859375, 'X_unit': -1, 'Zr_unit': 0.883056640625, 'DateTime': '2019-09-19 16:55:49', 'Y_unit': -1, 'Y': -25, 'X': -91, 'Z': 144, 'ID': 'ausitn', 'Z_unit': 1, 'Yr_unit': 0.3505859375, 'Xr': -1532, 'Yr': 5744, 'Zr': 14468})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:49', 'X_unit': -1, 'Y_unit': -1, 'Z_unit': 1, 'Xr': -1532, 'Yr': 5744, 'Zr': 14468, 'Xr_unit': -0.093505859375, 'Yr_unit': 0.3505859375, 'Zr_unit': 0.883056640625}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=64 : (key=None, value={'Xr_unit': -0.088623046875, 'X_unit': -3, 'Zr_unit': 0.88427734375, 'DateTime': '2019-09-19 16:55:49', 'Y_unit': -1, 'Y': -62, 'X': -295, 'Z': 76, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.35693359375, 'Xr': -1452, 'Yr': 5848, 'Zr': 14488})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:49', 'X_unit': -3, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1452, 'Yr': 5848, 'Zr': 14488, 'Xr_unit': -0.088623046875, 'Yr_unit': 0.35693359375, 'Zr_unit': 0.88427734375}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=65 : (key=None, value={'Xr_unit': -0.09423828125, 'X_unit': -2, 'Zr_unit': 0.8818359375, 'DateTime': '2019-09-19 16:55:49', 'Y_unit': -1, 'Y': -32, 'X': -175, 'Z': 99, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.3564453125, 'Xr': -1544, 'Yr': 5840, 'Zr': 14448})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:49', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1544, 'Yr': 5840, 'Zr': 14448, 'Xr_unit': -0.09423828125, 'Yr_unit': 0.3564453125, 'Zr_unit': 0.8818359375}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=66 : (key=None, value={'Xr_unit': -0.096923828125, 'X_unit': -2, 'Zr_unit': 0.8955078125, 'DateTime': '2019-09-19 16:55:49', 'Y_unit': -2, 'Y': -222, 'X': -159, 'Z': 107, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.355224609375, 'Xr': -1588, 'Yr': 5820, 'Zr': 14672})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:49', 'X_unit': -2, 'Y_unit': -2, 'Z_unit': 0, 'Xr': -1588, 'Yr': 5820, 'Zr': 14672, 'Xr_unit': -0.096923828125, 'Yr_unit': 0.355224609375, 'Zr_unit': 0.8955078125}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=67 : (key=None, value={'Xr_unit': -0.07958984375, 'X_unit': -2, 'Zr_unit': 0.89306640625, 'DateTime': '2019-09-19 16:55:50', 'Y_unit': 1, 'Y': 250, 'X': -157, 'Z': 138, 'ID': 'ausitn', 'Z_unit': 1, 'Yr_unit': 0.35205078125, 'Xr': -1304, 'Yr': 5768, 'Zr': 14632})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:50', 'X_unit': -2, 'Y_unit': 1, 'Z_unit': 1, 'Xr': -1304, 'Yr': 5768, 'Zr': 14632, 'Xr_unit': -0.07958984375, 'Yr_unit': 0.35205078125, 'Zr_unit': 0.89306640625}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=68 : (key=None, value={'Xr_unit': -0.09228515625, 'X_unit': -2, 'Zr_unit': 0.869873046875, 'DateTime': '2019-09-19 16:55:50', 'Y_unit': -1, 'Y': -11, 'X': -160, 'Z': 115, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.35400390625, 'Xr': -1512, 'Yr': 5800, 'Zr': 14252})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:50', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1512, 'Yr': 5800, 'Zr': 14252, 'Xr_unit': -0.09228515625, 'Yr_unit': 0.35400390625, 'Zr_unit': 0.869873046875}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=69 : (key=None, value={'Xr_unit': -0.0791015625, 'X_unit': -2, 'Zr_unit': 0.877685546875, 'DateTime': '2019-09-19 16:55:50', 'Y_unit': -1, 'Y': -24, 'X': -226, 'Z': 110, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.3525390625, 'Xr': -1296, 'Yr': 5776, 'Zr': 14380})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:50', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1296, 'Yr': 5776, 'Zr': 14380, 'Xr_unit': -0.0791015625, 'Yr_unit': 0.3525390625, 'Zr_unit': 0.877685546875}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=70 : (key=None, value={'Xr_unit': -0.08935546875, 'X_unit': -2, 'Zr_unit': 0.888671875, 'DateTime': '2019-09-19 16:55:50', 'Y_unit': -1, 'Y': -85, 'X': -186, 'Z': 86, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.349609375, 'Xr': -1464, 'Yr': 5728, 'Zr': 14560})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:50', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1464, 'Yr': 5728, 'Zr': 14560, 'Xr_unit': -0.08935546875, 'Yr_unit': 0.349609375, 'Zr_unit': 0.888671875}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=71 : (key=None, value={'Xr_unit': -0.109130859375, 'X_unit': -2, 'Zr_unit': 0.8818359375, 'DateTime': '2019-09-19 16:55:50', 'Y_unit': -1, 'Y': -68, 'X': -192, 'Z': 117, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.349853515625, 'Xr': -1788, 'Yr': 5732, 'Zr': 14448})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:50', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1788, 'Yr': 5732, 'Zr': 14448, 'Xr_unit': -0.109130859375, 'Yr_unit': 0.349853515625, 'Zr_unit': 0.8818359375}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=72 : (key=None, value={'Xr_unit': -0.09033203125, 'X_unit': -2, 'Zr_unit': 0.89794921875, 'DateTime': '2019-09-19 16:55:50', 'Y_unit': 0, 'Y': 34, 'X': -138, 'Z': 148, 'ID': 'ausitn', 'Z_unit': 1, 'Yr_unit': 0.34423828125, 'Xr': -1480, 'Yr': 5640, 'Zr': 14712})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:50', 'X_unit': -2, 'Y_unit': 0, 'Z_unit': 1, 'Xr': -1480, 'Yr': 5640, 'Zr': 14712, 'Xr_unit': -0.09033203125, 'Yr_unit': 0.34423828125, 'Zr_unit': 0.89794921875}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=73 : (key=None, value={'Xr_unit': -0.083984375, 'X_unit': -2, 'Zr_unit': 0.88720703125, 'DateTime': '2019-09-19 16:55:50', 'Y_unit': -1, 'Y': -54, 'X': -159, 'Z': 141, 'ID': 'ausitn', 'Z_unit': 1, 'Yr_unit': 0.348388671875, 'Xr': -1376, 'Yr': 5708, 'Zr': 14536})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:50', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 1, 'Xr': -1376, 'Yr': 5708, 'Zr': 14536, 'Xr_unit': -0.083984375, 'Yr_unit': 0.348388671875, 'Zr_unit': 0.88720703125}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=74 : (key=None, value={'Xr_unit': -0.096435546875, 'X_unit': -1, 'Zr_unit': 0.844970703125, 'DateTime': '2019-09-19 16:55:51', 'Y_unit': -2, 'Y': -154, 'X': -59, 'Z': 84, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.342529296875, 'Xr': -1580, 'Yr': 5612, 'Zr': 13844})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:51', 'X_unit': -1, 'Y_unit': -2, 'Z_unit': 0, 'Xr': -1580, 'Yr': 5612, 'Zr': 13844, 'Xr_unit': -0.096435546875, 'Yr_unit': 0.342529296875, 'Zr_unit': 0.844970703125}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=75 : (key=None, value={'Xr_unit': -0.0888671875, 'X_unit': -2, 'Zr_unit': 0.88525390625, 'DateTime': '2019-09-19 16:55:51', 'Y_unit': -2, 'Y': -255, 'X': -140, 'Z': 119, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.348388671875, 'Xr': -1456, 'Yr': 5708, 'Zr': 14504})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:51', 'X_unit': -2, 'Y_unit': -2, 'Z_unit': 0, 'Xr': -1456, 'Yr': 5708, 'Zr': 14504, 'Xr_unit': -0.0888671875, 'Yr_unit': 0.348388671875, 'Zr_unit': 0.88525390625}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=76 : (key=None, value={'Xr_unit': -0.103271484375, 'X_unit': -2, 'Zr_unit': 0.879150390625, 'DateTime': '2019-09-19 16:55:51', 'Y_unit': -1, 'Y': -35, 'X': -160, 'Z': 131, 'ID': 'ausitn', 'Z_unit': 1, 'Yr_unit': 0.35546875, 'Xr': -1692, 'Yr': 5824, 'Zr': 14404})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:51', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 1, 'Xr': -1692, 'Yr': 5824, 'Zr': 14404, 'Xr_unit': -0.103271484375, 'Yr_unit': 0.35546875, 'Zr_unit': 0.879150390625}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=77 : (key=None, value={'Xr_unit': -0.09912109375, 'X_unit': -1, 'Zr_unit': 0.884521484375, 'DateTime': '2019-09-19 16:55:51', 'Y_unit': -1, 'Y': -24, 'X': -108, 'Z': 129, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.35107421875, 'Xr': -1624, 'Yr': 5752, 'Zr': 14492})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:51', 'X_unit': -1, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1624, 'Yr': 5752, 'Zr': 14492, 'Xr_unit': -0.09912109375, 'Yr_unit': 0.35107421875, 'Zr_unit': 0.884521484375}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=78 : (key=None, value={'Xr_unit': -0.096923828125, 'X_unit': -2, 'Zr_unit': 0.88671875, 'DateTime': '2019-09-19 16:55:51', 'Y_unit': 0, 'Y': 20, 'X': -173, 'Z': 40, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.345703125, 'Xr': -1588, 'Yr': 5664, 'Zr': 14528})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:51', 'X_unit': -2, 'Y_unit': 0, 'Z_unit': 0, 'Xr': -1588, 'Yr': 5664, 'Zr': 14528, 'Xr_unit': -0.096923828125, 'Yr_unit': 0.345703125, 'Zr_unit': 0.88671875}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=79 : (key=None, value={'Xr_unit': -0.08837890625, 'X_unit': -2, 'Zr_unit': 0.89990234375, 'DateTime': '2019-09-19 16:55:51', 'Y_unit': -1, 'Y': -39, 'X': -132, 'Z': 138, 'ID': 'ausitn', 'Z_unit': 1, 'Yr_unit': 0.3515625, 'Xr': -1448, 'Yr': 5760, 'Zr': 14744})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:51', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 1, 'Xr': -1448, 'Yr': 5760, 'Zr': 14744, 'Xr_unit': -0.08837890625, 'Yr_unit': 0.3515625, 'Zr_unit': 0.89990234375}
# <pymongo.results.InsertOneResult object at 0x7fb861402a88>
# topic=step, partition=0, offset=80 : (key=None, value={'Xr_unit': -0.091552734375, 'X_unit': -2, 'Zr_unit': 0.89697265625, 'DateTime': '2019-09-19 16:55:51', 'Y_unit': -1, 'Y': -14, 'X': -135, 'Z': 92, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.346435546875, 'Xr': -1500, 'Yr': 5676, 'Zr': 14696})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:51', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1500, 'Yr': 5676, 'Zr': 14696, 'Xr_unit': -0.091552734375, 'Yr_unit': 0.346435546875, 'Zr_unit': 0.89697265625}
# <pymongo.results.InsertOneResult object at 0x7fb860331448>
# topic=step, partition=0, offset=81 : (key=None, value={'Xr_unit': -0.093017578125, 'X_unit': -2, 'Zr_unit': 0.86083984375, 'DateTime': '2019-09-19 16:55:51', 'Y_unit': -1, 'Y': -107, 'X': -219, 'Z': 98, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.3486328125, 'Xr': -1524, 'Yr': 5712, 'Zr': 14104})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:51', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1524, 'Yr': 5712, 'Zr': 14104, 'Xr_unit': -0.093017578125, 'Yr_unit': 0.3486328125, 'Zr_unit': 0.86083984375}
# <pymongo.results.InsertOneResult object at 0x7fb86264cf08>
# topic=step, partition=0, offset=82 : (key=None, value={'Xr_unit': -0.101318359375, 'X_unit': -2, 'Zr_unit': 0.873779296875, 'DateTime': '2019-09-19 16:55:51', 'Y_unit': -1, 'Y': -14, 'X': -197, 'Z': 87, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.345703125, 'Xr': -1660, 'Yr': 5664, 'Zr': 14316})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:55:51', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1660, 'Yr': 5664, 'Zr': 14316, 'Xr_unit': -0.101318359375, 'Yr_unit': 0.345703125, 'Zr_unit': 0.873779296875}
# ...
# <pymongo.results.InsertOneResult object at 0x7fb860374a48>
# topic=step, partition=0, offset=365 : (key=None, value={'Xr_unit': -0.0810546875, 'X_unit': -2, 'Zr_unit': 0.887451171875, 'DateTime': '2019-09-19 16:56:29', 'Y_unit': -1, 'Y': -60, 'X': -152, 'Z': 112, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.3564453125, 'Xr': -1328, 'Yr': 5840, 'Zr': 14540})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:29', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1328, 'Yr': 5840, 'Zr': 14540, 'Xr_unit': -0.0810546875, 'Yr_unit': 0.3564453125, 'Zr_unit': 0.887451171875}
# <pymongo.results.InsertOneResult object at 0x7fb860331108>
# topic=step, partition=0, offset=366 : (key=None, value={'Xr_unit': -0.098876953125, 'X_unit': -2, 'Zr_unit': 0.8798828125, 'DateTime': '2019-09-19 16:56:29', 'Y_unit': -1, 'Y': -33, 'X': -146, 'Z': 112, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.350341796875, 'Xr': -1620, 'Yr': 5740, 'Zr': 14416})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:29', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1620, 'Yr': 5740, 'Zr': 14416, 'Xr_unit': -0.098876953125, 'Yr_unit': 0.350341796875, 'Zr_unit': 0.8798828125}
# <pymongo.results.InsertOneResult object at 0x7fb860331308>
# topic=step, partition=0, offset=367 : (key=None, value={'Xr_unit': -0.08984375, 'X_unit': -2, 'Zr_unit': 0.87646484375, 'DateTime': '2019-09-19 16:56:29', 'Y_unit': -1, 'Y': -61, 'X': -179, 'Z': 131, 'ID': 'ausitn', 'Z_unit': 1, 'Yr_unit': 0.34912109375, 'Xr': -1472, 'Yr': 5720, 'Zr': 14360})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:29', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 1, 'Xr': -1472, 'Yr': 5720, 'Zr': 14360, 'Xr_unit': -0.08984375, 'Yr_unit': 0.34912109375, 'Zr_unit': 0.87646484375}
# <pymongo.results.InsertOneResult object at 0x7fb86033aa88>
# topic=step, partition=0, offset=368 : (key=None, value={'Xr_unit': -0.109130859375, 'X_unit': -2, 'Zr_unit': 0.863525390625, 'DateTime': '2019-09-19 16:56:30', 'Y_unit': -1, 'Y': -52, 'X': -177, 'Z': 115, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.3505859375, 'Xr': -1788, 'Yr': 5744, 'Zr': 14148})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:30', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1788, 'Yr': 5744, 'Zr': 14148, 'Xr_unit': -0.109130859375, 'Yr_unit': 0.3505859375, 'Zr_unit': 0.863525390625}
# <pymongo.results.InsertOneResult object at 0x7fb860331308>
# topic=step, partition=0, offset=369 : (key=None, value={'Xr_unit': -0.091552734375, 'X_unit': -2, 'Zr_unit': 0.87744140625, 'DateTime': '2019-09-19 16:56:30', 'Y_unit': 0, 'Y': 20, 'X': -184, 'Z': 111, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.353515625, 'Xr': -1500, 'Yr': 5792, 'Zr': 14376})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:30', 'X_unit': -2, 'Y_unit': 0, 'Z_unit': 0, 'Xr': -1500, 'Yr': 5792, 'Zr': 14376, 'Xr_unit': -0.091552734375, 'Yr_unit': 0.353515625, 'Zr_unit': 0.87744140625}
# <pymongo.results.InsertOneResult object at 0x7fb860331108>
# topic=step, partition=0, offset=370 : (key=None, value={'Xr_unit': -0.093505859375, 'X_unit': -2, 'Zr_unit': 0.871337890625, 'DateTime': '2019-09-19 16:56:30', 'Y_unit': -1, 'Y': -18, 'X': -189, 'Z': 106, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.352783203125, 'Xr': -1532, 'Yr': 5780, 'Zr': 14276})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:30', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1532, 'Yr': 5780, 'Zr': 14276, 'Xr_unit': -0.093505859375, 'Yr_unit': 0.352783203125, 'Zr_unit': 0.871337890625}
# <pymongo.results.InsertOneResult object at 0x7fb860374a48>
# topic=step, partition=0, offset=371 : (key=None, value={'Xr_unit': -0.107421875, 'X_unit': -2, 'Zr_unit': 0.89697265625, 'DateTime': '2019-09-19 16:56:30', 'Y_unit': -1, 'Y': -17, 'X': -217, 'Z': 119, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.3505859375, 'Xr': -1760, 'Yr': 5744, 'Zr': 14696})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:30', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1760, 'Yr': 5744, 'Zr': 14696, 'Xr_unit': -0.107421875, 'Yr_unit': 0.3505859375, 'Zr_unit': 0.89697265625}
# <pymongo.results.InsertOneResult object at 0x7fb860331108>
# topic=step, partition=0, offset=372 : (key=None, value={'Xr_unit': -0.092529296875, 'X_unit': -2, 'Zr_unit': 0.878173828125, 'DateTime': '2019-09-19 16:56:30', 'Y_unit': -1, 'Y': -9, 'X': -229, 'Z': 94, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.3525390625, 'Xr': -1516, 'Yr': 5776, 'Zr': 14388})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:30', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1516, 'Yr': 5776, 'Zr': 14388, 'Xr_unit': -0.092529296875, 'Yr_unit': 0.3525390625, 'Zr_unit': 0.878173828125}
# <pymongo.results.InsertOneResult object at 0x7fb860331308>
# topic=step, partition=0, offset=373 : (key=None, value={'Xr_unit': -0.1083984375, 'X_unit': -2, 'Zr_unit': 0.866943359375, 'DateTime': '2019-09-19 16:56:30', 'Y_unit': -2, 'Y': -251, 'X': -207, 'Z': 126, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.345703125, 'Xr': -1776, 'Yr': 5664, 'Zr': 14204})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:30', 'X_unit': -2, 'Y_unit': -2, 'Z_unit': 0, 'Xr': -1776, 'Yr': 5664, 'Zr': 14204, 'Xr_unit': -0.1083984375, 'Yr_unit': 0.345703125, 'Zr_unit': 0.866943359375}
# <pymongo.results.InsertOneResult object at 0x7fb86033aa88>
# topic=step, partition=0, offset=374 : (key=None, value={'Xr_unit': -0.098876953125, 'X_unit': -2, 'Zr_unit': 0.883056640625, 'DateTime': '2019-09-19 16:56:30', 'Y_unit': -1, 'Y': -70, 'X': -208, 'Z': 80, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.353271484375, 'Xr': -1620, 'Yr': 5788, 'Zr': 14468})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:30', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1620, 'Yr': 5788, 'Zr': 14468, 'Xr_unit': -0.098876953125, 'Yr_unit': 0.353271484375, 'Zr_unit': 0.883056640625}
# <pymongo.results.InsertOneResult object at 0x7fb860331308>
# topic=step, partition=0, offset=375 : (key=None, value={'Xr_unit': -0.08251953125, 'X_unit': -2, 'Zr_unit': 0.890869140625, 'DateTime': '2019-09-19 16:56:30', 'Y_unit': 0, 'Y': 45, 'X': -206, 'Z': 141, 'ID': 'ausitn', 'Z_unit': 1, 'Yr_unit': 0.347900390625, 'Xr': -1352, 'Yr': 5700, 'Zr': 14596})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:30', 'X_unit': -2, 'Y_unit': 0, 'Z_unit': 1, 'Xr': -1352, 'Yr': 5700, 'Zr': 14596, 'Xr_unit': -0.08251953125, 'Yr_unit': 0.347900390625, 'Zr_unit': 0.890869140625}
# <pymongo.results.InsertOneResult object at 0x7fb860331108>
# topic=step, partition=0, offset=376 : (key=None, value={'Xr_unit': -0.0908203125, 'X_unit': -2, 'Zr_unit': 0.88330078125, 'DateTime': '2019-09-19 16:56:30', 'Y_unit': -1, 'Y': -65, 'X': -184, 'Z': 117, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.349853515625, 'Xr': -1488, 'Yr': 5732, 'Zr': 14472})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:30', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1488, 'Yr': 5732, 'Zr': 14472, 'Xr_unit': -0.0908203125, 'Yr_unit': 0.349853515625, 'Zr_unit': 0.88330078125}
# <pymongo.results.InsertOneResult object at 0x7fb860374a48>
# topic=step, partition=0, offset=377 : (key=None, value={'Xr_unit': -0.10888671875, 'X_unit': -2, 'Zr_unit': 0.880859375, 'DateTime': '2019-09-19 16:56:30', 'Y_unit': -1, 'Y': -28, 'X': -163, 'Z': 112, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.348388671875, 'Xr': -1784, 'Yr': 5708, 'Zr': 14432})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:30', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1784, 'Yr': 5708, 'Zr': 14432, 'Xr_unit': -0.10888671875, 'Yr_unit': 0.348388671875, 'Zr_unit': 0.880859375}
# <pymongo.results.InsertOneResult object at 0x7fb860331108>
# topic=step, partition=0, offset=378 : (key=None, value={'Xr_unit': -0.098876953125, 'X_unit': -2, 'Zr_unit': 0.884033203125, 'DateTime': '2019-09-19 16:56:30', 'Y_unit': -1, 'Y': -63, 'X': -196, 'Z': 83, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.348388671875, 'Xr': -1620, 'Yr': 5708, 'Zr': 14484})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:30', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1620, 'Yr': 5708, 'Zr': 14484, 'Xr_unit': -0.098876953125, 'Yr_unit': 0.348388671875, 'Zr_unit': 0.884033203125}
# <pymongo.results.InsertOneResult object at 0x7fb860331308>
# topic=step, partition=0, offset=379 : (key=None, value={'Xr_unit': -0.09130859375, 'X_unit': -2, 'Zr_unit': 0.866943359375, 'DateTime': '2019-09-19 16:56:30', 'Y_unit': -1, 'Y': -102, 'X': -188, 'Z': 109, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.34814453125, 'Xr': -1496, 'Yr': 5704, 'Zr': 14204})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:30', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1496, 'Yr': 5704, 'Zr': 14204, 'Xr_unit': -0.09130859375, 'Yr_unit': 0.34814453125, 'Zr_unit': 0.866943359375}
# <pymongo.results.InsertOneResult object at 0x7fb86033aa88>
# topic=step, partition=0, offset=380 : (key=None, value={'Xr_unit': -0.09716796875, 'X_unit': -2, 'Zr_unit': 0.88916015625, 'DateTime': '2019-09-19 16:56:30', 'Y_unit': -1, 'Y': -106, 'X': -172, 'Z': 112, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.35009765625, 'Xr': -1592, 'Yr': 5736, 'Zr': 14568})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:30', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1592, 'Yr': 5736, 'Zr': 14568, 'Xr_unit': -0.09716796875, 'Yr_unit': 0.35009765625, 'Zr_unit': 0.88916015625}
# <pymongo.results.InsertOneResult object at 0x7fb860331308>
# topic=step, partition=0, offset=381 : (key=None, value={'Xr_unit': -0.0986328125, 'X_unit': -1, 'Zr_unit': 0.88818359375, 'DateTime': '2019-09-19 16:56:31', 'Y_unit': -1, 'Y': -34, 'X': -120, 'Z': 141, 'ID': 'ausitn', 'Z_unit': 1, 'Yr_unit': 0.34521484375, 'Xr': -1616, 'Yr': 5656, 'Zr': 14552})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:31', 'X_unit': -1, 'Y_unit': -1, 'Z_unit': 1, 'Xr': -1616, 'Yr': 5656, 'Zr': 14552, 'Xr_unit': -0.0986328125, 'Yr_unit': 0.34521484375, 'Zr_unit': 0.88818359375}
# <pymongo.results.InsertOneResult object at 0x7fb860331108>
# topic=step, partition=0, offset=382 : (key=None, value={'Xr_unit': -0.09228515625, 'X_unit': -1, 'Zr_unit': 0.880615234375, 'DateTime': '2019-09-19 16:56:31', 'Y_unit': 1, 'Y': 249, 'X': -123, 'Z': 113, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.34814453125, 'Xr': -1512, 'Yr': 5704, 'Zr': 14428})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:31', 'X_unit': -1, 'Y_unit': 1, 'Z_unit': 0, 'Xr': -1512, 'Yr': 5704, 'Zr': 14428, 'Xr_unit': -0.09228515625, 'Yr_unit': 0.34814453125, 'Zr_unit': 0.880615234375}
# <pymongo.results.InsertOneResult object at 0x7fb860374a48>
# topic=step, partition=0, offset=383 : (key=None, value={'Xr_unit': -0.09716796875, 'X_unit': -2, 'Zr_unit': 0.8935546875, 'DateTime': '2019-09-19 16:56:31', 'Y_unit': -1, 'Y': -22, 'X': -193, 'Z': 104, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.345947265625, 'Xr': -1592, 'Yr': 5668, 'Zr': 14640})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:31', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1592, 'Yr': 5668, 'Zr': 14640, 'Xr_unit': -0.09716796875, 'Yr_unit': 0.345947265625, 'Zr_unit': 0.8935546875}
# <pymongo.results.InsertOneResult object at 0x7fb860331108>
# topic=step, partition=0, offset=384 : (key=None, value={'Xr_unit': -0.097412109375, 'X_unit': -2, 'Zr_unit': 0.88623046875, 'DateTime': '2019-09-19 16:56:31', 'Y_unit': -1, 'Y': -62, 'X': -217, 'Z': 91, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.351318359375, 'Xr': -1596, 'Yr': 5756, 'Zr': 14520})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:31', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1596, 'Yr': 5756, 'Zr': 14520, 'Xr_unit': -0.097412109375, 'Yr_unit': 0.351318359375, 'Zr_unit': 0.88623046875}
# <pymongo.results.InsertOneResult object at 0x7fb860331308>
# topic=step, partition=0, offset=385 : (key=None, value={'Xr_unit': -0.107177734375, 'X_unit': -1, 'Zr_unit': 0.878173828125, 'DateTime': '2019-09-19 16:56:31', 'Y_unit': -1, 'Y': -36, 'X': -104, 'Z': 130, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.345947265625, 'Xr': -1756, 'Yr': 5668, 'Zr': 14388})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:31', 'X_unit': -1, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1756, 'Yr': 5668, 'Zr': 14388, 'Xr_unit': -0.107177734375, 'Yr_unit': 0.345947265625, 'Zr_unit': 0.878173828125}
# <pymongo.results.InsertOneResult object at 0x7fb86033aa88>
# topic=step, partition=0, offset=386 : (key=None, value={'Xr_unit': -0.099365234375, 'X_unit': -1, 'Zr_unit': 0.885498046875, 'DateTime': '2019-09-19 16:56:31', 'Y_unit': -1, 'Y': -28, 'X': -100, 'Z': 116, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.35546875, 'Xr': -1628, 'Yr': 5824, 'Zr': 14508})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:31', 'X_unit': -1, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1628, 'Yr': 5824, 'Zr': 14508, 'Xr_unit': -0.099365234375, 'Yr_unit': 0.35546875, 'Zr_unit': 0.885498046875}
# <pymongo.results.InsertOneResult object at 0x7fb860331308>
# topic=step, partition=0, offset=387 : (key=None, value={'Xr_unit': -0.089111328125, 'X_unit': -2, 'Zr_unit': 0.897216796875, 'DateTime': '2019-09-19 16:56:31', 'Y_unit': -1, 'Y': -38, 'X': -204, 'Z': 112, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.3525390625, 'Xr': -1460, 'Yr': 5776, 'Zr': 14700})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:31', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1460, 'Yr': 5776, 'Zr': 14700, 'Xr_unit': -0.089111328125, 'Yr_unit': 0.3525390625, 'Zr_unit': 0.897216796875}
# <pymongo.results.InsertOneResult object at 0x7fb860331108>
# topic=step, partition=0, offset=388 : (key=None, value={'Xr_unit': -0.08740234375, 'X_unit': -2, 'Zr_unit': 0.8798828125, 'DateTime': '2019-09-19 16:56:32', 'Y_unit': -1, 'Y': -51, 'X': -213, 'Z': 70, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.35205078125, 'Xr': -1432, 'Yr': 5768, 'Zr': 14416})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:32', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1432, 'Yr': 5768, 'Zr': 14416, 'Xr_unit': -0.08740234375, 'Yr_unit': 0.35205078125, 'Zr_unit': 0.8798828125}
# <pymongo.results.InsertOneResult object at 0x7fb860374a48>
# topic=step, partition=0, offset=389 : (key=None, value={'Xr_unit': -0.09375, 'X_unit': -2, 'Zr_unit': 0.883544921875, 'DateTime': '2019-09-19 16:56:32', 'Y_unit': -1, 'Y': -75, 'X': -191, 'Z': 118, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.35107421875, 'Xr': -1536, 'Yr': 5752, 'Zr': 14476})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:32', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1536, 'Yr': 5752, 'Zr': 14476, 'Xr_unit': -0.09375, 'Yr_unit': 0.35107421875, 'Zr_unit': 0.883544921875}
# <pymongo.results.InsertOneResult object at 0x7fb860331108>
# topic=step, partition=0, offset=390 : (key=None, value={'Xr_unit': -0.109375, 'X_unit': -2, 'Zr_unit': 0.887451171875, 'DateTime': '2019-09-19 16:56:32', 'Y_unit': -1, 'Y': -39, 'X': -140, 'Z': 101, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.3515625, 'Xr': -1792, 'Yr': 5760, 'Zr': 14540})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:32', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1792, 'Yr': 5760, 'Zr': 14540, 'Xr_unit': -0.109375, 'Yr_unit': 0.3515625, 'Zr_unit': 0.887451171875}
# <pymongo.results.InsertOneResult object at 0x7fb860331308>
# topic=step, partition=0, offset=391 : (key=None, value={'Xr_unit': -0.0947265625, 'X_unit': -2, 'Zr_unit': 0.889892578125, 'DateTime': '2019-09-19 16:56:32', 'Y_unit': -1, 'Y': -16, 'X': -164, 'Z': 109, 'ID': 'ausitn', 'Z_unit': 0, 'Yr_unit': 0.335205078125, 'Xr': -1552, 'Yr': 5492, 'Zr': 14580})
# json= {'device_id': 'ausitn', 'timestamp': '2019-09-19 16:56:32', 'X_unit': -2, 'Y_unit': -1, 'Z_unit': 0, 'Xr': -1552, 'Yr': 5492, 'Zr': 14580, 'Xr_unit': -0.0947265625, 'Yr_unit': 0.335205078125, 'Zr_unit': 0.889892578125}
# <pymongo.results.InsertOneResult object at 0x7fb86033aa88>
# type ==> <class 'KeyboardInterrupt'>
# value ==>
# traceback ==> file name: <ipython-input-23-cc88af2f6c2c>
# traceback ==> line no: 40
# traceback ==> function name: <module>
