# %%
from kafka import KafkaProducer
import sys, random, datetime, time, json

while True:
    if __name__ == "__main__":
        # 設定要連線到Kafka集群的相關設定, 並產生一個Kafka的Producer的實例
        producer1 = KafkaProducer(
            # 指定Kafka集群伺服器
            bootstrap_servers = ["kafka:9092"],
            # 指定msgKey的序列化器, 若Key為None, 無法序列化, 透過producer直接給值
            #key_serializer = str.encode,
            # 指定msgValue的序列化器
            #value_serializer = str.encode,
            value_serializer = lambda m: json.dumps(m).encode('ascii'),
        )

        producer2 = KafkaProducer(
            # 指定Kafka集群伺服器
            bootstrap_servers = ["kafka:9092"],
            # 指定msgKey的序列化器, 若Key為None, 無法序列化, 透過producer直接給值
            #key_serializer = str.encode,
            # 指定msgValue的序列化器
            #value_serializer = str.encode,
            value_serializer = lambda m: json.dumps(m).encode('ascii'),
        )


        try:
            device_id = "001"
            t = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            temp = round(random.uniform(18, 30), 2)
            humidity = random.randint(0, 100)
            rd = random.random()
            tt = {"device_id": device_id, "timestamp": t, "Temperature": temp, 'rd': rd}
            hh = {"device_id": device_id, "timestamp": t, "Humidity": humidity, 'rd': rd}

            print("Start sending messages ...")
            # 產生要發佈到Kafka的訊息
    #         producer1.send(topic="temperature", value=tt)
    #         producer2.send(topic="humidity", value=hh)
            # producer.send(topic=topicName, key=msgKey, value=msgValue)
            future1 = producer1.send(topic="temperature", value=tt)
            record_metadata1 = future1.get(timeout=10)
            print(record_metadata1)

            future2 = producer2.send(topic="humidity", value=hh)
            record_metadata2 = future2.get(timeout=10)
            print(record_metadata2)
            print("Message sending completed!")

        except Exception as e:
            # 錯誤處理
            e_type, e_value, e_traceback = sys.exc_info()
            print("type ==> %s" % (e_type))
            print("value ==> %s" % (e_value))
            print("traceback ==> file name: %s" % (e_traceback.tb_frame.f_code.co_filename))
            print("traceback ==> line no: %s" % (e_traceback.tb_lineno))
            print("traceback ==> function name: %s" % (e_traceback.tb_frame.f_code.co_name))


        finally:
            # 關掉Producer實例的連線
            producer1.close()
            producer2.close()
            time.sleep(2)
# Out:
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=55, timestamp=-1, checksum=518250021, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=55, timestamp=-1, checksum=-1903812344, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=56, timestamp=-1, checksum=-1874266033, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=56, timestamp=-1, checksum=1159607689, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=57, timestamp=-1, checksum=1494983575, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=57, timestamp=-1, checksum=1451875939, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=58, timestamp=-1, checksum=-575330373, serialized_key_size=-1, serialized_value_size=105)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=58, timestamp=-1, checksum=-291060692, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=59, timestamp=-1, checksum=540838450, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=59, timestamp=-1, checksum=1948758190, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=60, timestamp=-1, checksum=1190478690, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=60, timestamp=-1, checksum=1407479046, serialized_key_size=-1, serialized_value_size=97)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=61, timestamp=-1, checksum=1455362220, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=61, timestamp=-1, checksum=1029085659, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=62, timestamp=-1, checksum=158622341, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=62, timestamp=-1, checksum=-620443722, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=63, timestamp=-1, checksum=-1062712105, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=63, timestamp=-1, checksum=-1513820295, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=64, timestamp=-1, checksum=-780658206, serialized_key_size=-1, serialized_value_size=103)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=64, timestamp=-1, checksum=-582415783, serialized_key_size=-1, serialized_value_size=97)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset
serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=130, timestamp=-1, checksum=580518605, serialized_key_size=-1, serialized_value_size=97)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=131, timestamp=-1, checksum=-277262730, serialized_key_size=-1, serialized_value_size=105)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=131, timestamp=-1, checksum=811134165, serialized_key_size=-1, serialized_value_size=99)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=132, timestamp=-1, checksum=439306208, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=132, timestamp=-1, checksum=-766877753, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=133, timestamp=-1, checksum=-154559396, serialized_key_size=-1, serialized_value_size=105)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=133, timestamp=-1, checksum=98520515, serialized_key_size=-1, serialized_value_size=99)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=134, timestamp=-1, checksum=75477385, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=134, timestamp=-1, checksum=-1418090236, serialized_key_size=-1, serialized_value_size=97)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=135, timestamp=-1, checksum=-417404650, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=135, timestamp=-1, checksum=-2054888569, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=136, timestamp=-1, checksum=1735768117, serialized_key_size=-1, serialized_value_size=103)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=136, timestamp=-1, checksum=285385666, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=137, timestamp=-1, checksum=-1943337806, serialized_key_size=-1, serialized_value_size=105)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=137, timestamp=-1, checksum=-415815603, serialized_key_size=-1, serialized_value_size=99)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=138, timestamp=-1, checksum=-673415908, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=138, timestamp=-1, checksum=1378682330, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=139, timestamp=-1, checksum=-283486976, serialized_key_size=-1, serialized_value_size=103)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=139, timestamp=-1, checksum=-783713528, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=140, timestamp=-1, checksum=-736063229, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=140, timestamp=-1, checksum=675208282, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=141, timestamp=-1, checksum=-871298990, serialized_key_size=-1, serialized_value_size=105)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=141, timestamp=-1, checksum=709892615, serialized_key_size=-1, serialized_value_size=99)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=142, timestamp=-1, checksum=-1517069186, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=142, timestamp=-1, checksum=-1923959028, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=143, timestamp=-1, checksum=-1802275489, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=143, timestamp=-1, checksum=221220653, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=144, timestamp=-1, checksum=-163276271, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=144, timestamp=-1, checksum=2077270397, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=145, timestamp=-1, checksum=-1404634980, serialized_key_size=-1, serialized_value_size=103)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=145, timestamp=-1, checksum=1770845651, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=146, timestamp=-1, checksum=-1929844315, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=146, timestamp=-1, checksum=-1342434254, serialized_key_size=-1, serialized_value_size=99)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=147, timestamp=-1, checksum=-558558959, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=147, timestamp=-1, checksum=368597519, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=148, timestamp=-1, checksum=975478380, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=148, timestamp=-1, checksum=574638134, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=149, timestamp=-1, checksum=1411231884, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=149, timestamp=-1, checksum=-1843560291, serialized_key_size=-1, serialized_value_size=97)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=150, timestamp=-1, checksum=-1906789483, serialized_key_size=-1, serialized_value_size=103)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=150, timestamp=-1, checksum=-917973787, serialized_key_size=-1, serialized_value_size=97)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=151, timestamp=-1, checksum=-758668130, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=151, timestamp=-1, checksum=-259803235, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=152, timestamp=-1, checksum=1810731338, serialized_key_size=-1, serialized_value_size=103)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=152, timestamp=-1, checksum=1886884572, serialized_key_size=-1, serialized_value_size=97)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=153, timestamp=-1, checksum=-1326669483, serialized_key_size=-1, serialized_value_size=105)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=153, timestamp=-1, checksum=-1487715920, serialized_key_size=-1, serialized_value_size=99)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=154, timestamp=-1, checksum=1415858675, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=154, timestamp=-1, checksum=1165946272, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=155, timestamp=-1, checksum=1000425225, serialized_key_size=-1, serialized_value_size=105)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=155, timestamp=-1, checksum=2054087993, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=156, timestamp=-1, checksum=763628809, serialized_key_size=-1, serialized_value_size=103)
# ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1006, timestamp=-1, checksum=-338825798, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1006, timestamp=-1, checksum=621837364, serialized_key_size=-1, serialized_value_size=99)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1007, timestamp=-1, checksum=1751227713, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1007, timestamp=-1, checksum=233683683, serialized_key_size=-1, serialized_value_size=97)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1008, timestamp=-1, checksum=889151039, serialized_key_size=-1, serialized_value_size=105)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1008, timestamp=-1, checksum=315775875, serialized_key_size=-1, serialized_value_size=99)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1009, timestamp=-1, checksum=1172281338, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1009, timestamp=-1, checksum=-1359373366, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1010, timestamp=-1, checksum=-1252922321, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1010, timestamp=-1, checksum=-853107301, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1011, timestamp=-1, checksum=-1250470899, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1011, timestamp=-1, checksum=83145622, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1012, timestamp=-1, checksum=-1275957391, serialized_key_size=-1, serialized_value_size=106)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1012, timestamp=-1, checksum=2135095146, serialized_key_size=-1, serialized_value_size=100)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1013, timestamp=-1, checksum=1961168173, serialized_key_size=-1, serialized_value_size=105)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1013, timestamp=-1, checksum=30455687, serialized_key_size=-1, serialized_value_size=99)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1014, timestamp=-1, checksum=-500261839, serialized_key_size=-1, serialized_value_size=105)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1014, timestamp=-1, checksum=-2074544254, serialized_key_size=-1, serialized_value_size=99)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1015, timestamp=-1, checksum=278194661, serialized_key_size=-1, serialized_value_size=103)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1015, timestamp=-1, checksum=-1742697009, serialized_key_size=-1, serialized_value_size=97)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1016, timestamp=-1, checksum=1747478209, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1016, timestamp=-1, checksum=852953595, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1017, timestamp=-1, checksum=1321621537, serialized_key_size=-1, serialized_value_size=103)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1017, timestamp=-1, checksum=-1541995051, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1018, timestamp=-1, checksum=236387624, serialized_key_size=-1, serialized_value_size=105)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1018, timestamp=-1, checksum=-531972465, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1019, timestamp=-1, checksum=-749685466, serialized_key_size=-1, serialized_value_size=105)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1019, timestamp=-1, checksum=701528234, serialized_key_size=-1, serialized_value_size=100)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1020, timestamp=-1, checksum=-349260596, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1020, timestamp=-1, checksum=-514443250, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1021, timestamp=-1, checksum=2135989272, serialized_key_size=-1, serialized_value_size=103)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1021, timestamp=-1, checksum=1463784691, serialized_key_size=-1, serialized_value_size=97)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1022, timestamp=-1, checksum=234587068, serialized_key_size=-1, serialized_value_size=105)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1022, timestamp=-1, checksum=1811198406, serialized_key_size=-1, serialized_value_size=99)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1023, timestamp=-1, checksum=584685275, serialized_key_size=-1, serialized_value_size=105)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1023, timestamp=-1, checksum=-2051402821, serialized_key_size=-1, serialized_value_size=99)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1024, timestamp=-1, checksum=-2035372528, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1024, timestamp=-1, checksum=-1281343300, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1025, timestamp=-1, checksum=152725701, serialized_key_size=-1, serialized_value_size=103)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1025, timestamp=-1, checksum=206208732, serialized_key_size=-1, serialized_value_size=97)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1026, timestamp=-1, checksum=360234593, serialized_key_size=-1, serialized_value_size=105)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1026, timestamp=-1, checksum=-555050780, serialized_key_size=-1, serialized_value_size=99)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1027, timestamp=-1, checksum=-1720200529, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1027, timestamp=-1, checksum=1685947163, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1028, timestamp=-1, checksum=-1546170639, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1028, timestamp=-1, checksum=1479631414, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1029, timestamp=-1, checksum=-806533738, serialized_key_size=-1, serialized_value_size=105)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1029, timestamp=-1, checksum=1992365637, serialized_key_size=-1, serialized_value_size=99)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1030, timestamp=-1, checksum=-780319204, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1030, timestamp=-1, checksum=-1169521717, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1031, timestamp=-1, checksum=385708368, serialized_key_size=-1, serialized_value_size=106)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1031, timestamp=-1, checksum=-1654724186, serialized_key_size=-1, serialized_value_size=99)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1032, timestamp=-1, checksum=-2047130015, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1032, timestamp=-1, checksum=-494072159, serialized_key_size=-1, serialized_value_size=97)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1033, timestamp=-1, checksum=-1997458301, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1033, timestamp=-1, checksum=1038237448, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1034, timestamp=-1, checksum=1416761719, serialized_key_size=-1, serialized_value_size=105)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1034, timestamp=-1, checksum=-253424959, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1035, timestamp=-1, checksum=1896482673, serialized_key_size=-1, serialized_value_size=105)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1035, timestamp=-1, checksum=1527581197, serialized_key_size=-1, serialized_value_size=99)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1036, timestamp=-1, checksum=1224417023, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1036, timestamp=-1, checksum=-614641187, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1037, timestamp=-1, checksum=-268997273, serialized_key_size=-1, serialized_value_size=104)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1037, timestamp=-1, checksum=-996372376, serialized_key_size=-1, serialized_value_size=98)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=1038, timestamp=-1, checksum=-1379663924, serialized_key_size=-1, serialized_value_size=105)
# RecordMetadata(topic='humidity', partition=0, topic_partition=TopicPartition(topic='humidity', partition=0), offset=1038, timestamp=-1, checksum=-705991716, serialized_key_size=-1, serialized_value_size=99)
# Message sending completed!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-e84adeac877e> in <module>()
#      63             producer1.close()
#      64             producer2.close()
# ---> 65             time.sleep(2)
#
# KeyboardInterrupt:
